# %%
import pandas as pd

# %% [markdown]
# Put the results list in a dataframe

# %%
resultsList = pd.read_csv("./data2/results-list.csv")

# %% [markdown]
# Add a column type specifying the type of model used (classification, regression...)

# %%
serie = []
for i in resultsList['results']:
    serie.append(i.split("-")[2].split(".")[0])
#print(serie)

serie = pd.Series(serie)

resultsList['type'] = serie

# %% [markdown]
# For each row in the dataframe, open the corresponding results file, compute the metrics and add them to the dataframe

# %%
accuracy = []
precision = []
recall = []
specificity = []
npv = []

for i in resultsList['results']:
    dfTemp = pd.read_csv(i)
    dfMean = dfTemp.groupby(['sr']).mean().drop(['t'],axis=1)
    dfMean['accuracy']= (dfMean['TP']+dfMean['TN']) / (dfMean['TP']+dfMean['TN']+dfMean['FN']+dfMean['FP'])
    dfMean['precision']= (dfMean['TP']) / (dfMean['TP']+dfMean['FP'])
    dfMean['recall']= (dfMean['TP']) / (dfMean['TP']+dfMean['FN'])
    dfMean['specificity']= (dfMean['TN']) / (dfMean['TN']+dfMean['FP'])
    dfMean['npv']= (dfMean['TN']) / (dfMean['TN']+dfMean['FN'])
    accuracy.append(dfMean['accuracy'].mean())
    precision.append(dfMean['precision'].mean())
    recall.append(dfMean['recall'].mean())
    specificity.append(dfMean['specificity'].mean())
    npv.append(dfMean['npv'].mean())
resultsList['accuracy'] = pd.Series(accuracy)
resultsList['precision'] = pd.Series(precision)
resultsList['recall'] = pd.Series(recall)
resultsList['specificity'] = pd.Series(specificity)
resultsList['npv'] = pd.Series(npv)
resultsList
# Out:
#        class_weight criterion    file  max_depth  max_features  \
# 0               NaN   entropy  Apache        NaN           NaN
# 1               NaN       mse  Apache        NaN           NaN
# 2               NaN   entropy  Apache        NaN           NaN
# 3               NaN       mse  Apache        NaN           NaN
# 4               NaN   entropy  Apache        NaN           NaN
# 5               NaN       mse  Apache        NaN           NaN
# 6               NaN   entropy  Apache        NaN           NaN
# 7               NaN       mse  Apache        NaN           NaN
# 8               NaN   entropy  Apache        NaN           NaN
# 9               NaN       mse  Apache        NaN           NaN
# 10              NaN   entropy  Apache        NaN           NaN
# 11              NaN       mse  Apache        NaN           NaN
# 12              NaN   entropy  Apache        NaN           NaN
# 13              NaN       mse  Apache        NaN           NaN
# 14              NaN   entropy  Apache        NaN           NaN
# 15              NaN       mse  Apache        NaN           NaN
# 16              NaN   entropy  Apache        NaN           NaN
# 17              NaN       mse  Apache        NaN           NaN
# 18              NaN   entropy  Apache        NaN           NaN
# 19              NaN       mse  Apache        NaN           NaN
# 20              NaN   entropy  Apache        NaN           NaN
# 21              NaN       mse  Apache        NaN           NaN
# 22              NaN   entropy  Apache        NaN           NaN
# 23              NaN       mse  Apache        NaN           NaN
# 24              NaN   entropy  Apache        NaN           NaN
# 25              NaN       mse  Apache        NaN           NaN
# 26              NaN   entropy  Apache        NaN           NaN
# 27              NaN       mse  Apache        NaN           NaN
# 28              NaN   entropy  Apache        NaN           NaN
# 29              NaN       mse  Apache        NaN           NaN
# ...             ...       ...     ...        ...           ...
# 16170           NaN      gini  HIPAcc       90.0           NaN
# 16171           NaN       mae  HIPAcc       90.0           NaN
# 16172           NaN      gini  HIPAcc       90.0           NaN
# 16173           NaN       mae  HIPAcc       90.0           NaN
# 16174           NaN      gini  HIPAcc       90.0           NaN
# 16175           NaN       mae  HIPAcc       90.0           NaN
# 16176           NaN      gini  HIPAcc       90.0           NaN
# 16177           NaN       mae  HIPAcc       90.0           NaN
# 16178           NaN      gini  HIPAcc       90.0           NaN
# 16179           NaN       mae  HIPAcc       90.0           NaN
# 16180           NaN      gini  HIPAcc       90.0           NaN
# 16181           NaN       mae  HIPAcc       90.0           NaN
# 16182           NaN      gini  HIPAcc       90.0           NaN
# 16183           NaN       mae  HIPAcc       90.0           NaN
# 16184           NaN      gini  HIPAcc       90.0           NaN
# 16185           NaN       mae  HIPAcc       90.0           NaN
# 16186           NaN      gini  HIPAcc       90.0           NaN
# 16187           NaN       mae  HIPAcc       90.0           NaN
# 16188           NaN      gini  HIPAcc       90.0           NaN
# 16189           NaN       mae  HIPAcc       90.0           NaN
# 16190           NaN      gini  HIPAcc       90.0           NaN
# 16191           NaN       mae  HIPAcc       90.0           NaN
# 16192           NaN      gini  HIPAcc       90.0           NaN
# 16193           NaN       mae  HIPAcc       90.0           NaN
# 16194           NaN      gini  HIPAcc       90.0           NaN
# 16195           NaN       mae  HIPAcc       90.0           NaN
# 16196           NaN      gini  HIPAcc       90.0           NaN
# 16197           NaN       mae  HIPAcc       90.0           NaN
# 16198           NaN      gini  HIPAcc       90.0           NaN
# 16199           NaN       mae  HIPAcc       90.0           NaN
#
#        max_leaf_nodes  min_impurity_decrease  min_samples_leaf  \
# 0                  10           1.000000e-07                 1
# 1                  10           1.000000e-07                 1
# 2                  10           1.000000e-07                 2
# 3                  10           1.000000e-07                 2
# 4                  10           1.000000e-07                 4
# 5                  10           1.000000e-07                 4
# 6                  10           1.000000e-07                 6
# 7                  10           1.000000e-07                 6
# 8                  10           1.000000e-07                 8
# 9                  10           1.000000e-07                 8
# 10                 10           1.000000e-07                10
# 11                 10           1.000000e-07                10
# 12                 20           1.000000e-07                 1
# 13                 20           1.000000e-07                 1
# 14                 20           1.000000e-07                 2
# 15                 20           1.000000e-07                 2
# 16                 20           1.000000e-07                 4
# 17                 20           1.000000e-07                 4
# 18                 20           1.000000e-07                 6
# 19                 20           1.000000e-07                 6
# 20                 20           1.000000e-07                 8
# 21                 20           1.000000e-07                 8
# 22                 20           1.000000e-07                10
# 23                 20           1.000000e-07                10
# 24                 30           1.000000e-07                 1
# 25                 30           1.000000e-07                 1
# 26                 30           1.000000e-07                 2
# 27                 30           1.000000e-07                 2
# 28                 30           1.000000e-07                 4
# 29                 30           1.000000e-07                 4
# ...               ...                    ...               ...
# 16170              70           1.000000e-07                 6
# 16171              70           1.000000e-07                 6
# 16172              70           1.000000e-07                 8
# 16173              70           1.000000e-07                 8
# 16174              70           1.000000e-07                10
# 16175              70           1.000000e-07                10
# 16176              80           1.000000e-07                 1
# 16177              80           1.000000e-07                 1
# 16178              80           1.000000e-07                 2
# 16179              80           1.000000e-07                 2
# 16180              80           1.000000e-07                 4
# 16181              80           1.000000e-07                 4
# 16182              80           1.000000e-07                 6
# 16183              80           1.000000e-07                 6
# 16184              80           1.000000e-07                 8
# 16185              80           1.000000e-07                 8
# 16186              80           1.000000e-07                10
# 16187              80           1.000000e-07                10
# 16188              90           1.000000e-07                 1
# 16189              90           1.000000e-07                 1
# 16190              90           1.000000e-07                 2
# 16191              90           1.000000e-07                 2
# 16192              90           1.000000e-07                 4
# 16193              90           1.000000e-07                 4
# 16194              90           1.000000e-07                 6
# 16195              90           1.000000e-07                 6
# 16196              90           1.000000e-07                 8
# 16197              90           1.000000e-07                 8
# 16198              90           1.000000e-07                10
# 16199              90           1.000000e-07                10
#
#        min_samples_split  min_weight_fraction_leaf  presort  random_state  \
# 0                      2                       0.0    False           NaN
# 1                      2                       0.0    False           NaN
# 2                      2                       0.0    False           NaN
# 3                      2                       0.0    False           NaN
# 4                      2                       0.0    False           NaN
# 5                      2                       0.0    False           NaN
# 6                      2                       0.0    False           NaN
# 7                      2                       0.0    False           NaN
# 8                      2                       0.0    False           NaN
# 9                      2                       0.0    False           NaN
# 10                     2                       0.0    False           NaN
# 11                     2                       0.0    False           NaN
# 12                     2                       0.0    False           NaN
# 13                     2                       0.0    False           NaN
# 14                     2                       0.0    False           NaN
# 15                     2                       0.0    False           NaN
# 16                     2                       0.0    False           NaN
# 17                     2                       0.0    False           NaN
# 18                     2                       0.0    False           NaN
# 19                     2                       0.0    False           NaN
# 20                     2                       0.0    False           NaN
# 21                     2                       0.0    False           NaN
# 22                     2                       0.0    False           NaN
# 23                     2                       0.0    False           NaN
# 24                     2                       0.0    False           NaN
# 25                     2                       0.0    False           NaN
# 26                     2                       0.0    False           NaN
# 27                     2                       0.0    False           NaN
# 28                     2                       0.0    False           NaN
# 29                     2                       0.0    False           NaN
# ...                  ...                       ...      ...           ...
# 16170                  2                       0.0    False           NaN
# 16171                  2                       0.0    False           NaN
# 16172                  2                       0.0    False           NaN
# 16173                  2                       0.0    False           NaN
# 16174                  2                       0.0    False           NaN
# 16175                  2                       0.0    False           NaN
# 16176                  2                       0.0    False           NaN
# 16177                  2                       0.0    False           NaN
# 16178                  2                       0.0    False           NaN
# 16179                  2                       0.0    False           NaN
# 16180                  2                       0.0    False           NaN
# 16181                  2                       0.0    False           NaN
# 16182                  2                       0.0    False           NaN
# 16183                  2                       0.0    False           NaN
# 16184                  2                       0.0    False           NaN
# 16185                  2                       0.0    False           NaN
# 16186                  2                       0.0    False           NaN
# 16187                  2                       0.0    False           NaN
# 16188                  2                       0.0    False           NaN
# 16189                  2                       0.0    False           NaN
# 16190                  2                       0.0    False           NaN
# 16191                  2                       0.0    False           NaN
# 16192                  2                       0.0    False           NaN
# 16193                  2                       0.0    False           NaN
# 16194                  2                       0.0    False           NaN
# 16195                  2                       0.0    False           NaN
# 16196                  2                       0.0    False           NaN
# 16197                  2                       0.0    False           NaN
# 16198                  2                       0.0    False           NaN
# 16199                  2                       0.0    False           NaN
#
#                                       results splitter            type  \
# 0      ./data2/Apache-0001-classification.csv     best  classification
# 1          ./data2/Apache-0001-regression.csv     best      regression
# 2      ./data2/Apache-0002-classification.csv     best  classification
# 3          ./data2/Apache-0002-regression.csv     best      regression
# 4      ./data2/Apache-0003-classification.csv     best  classification
# 5          ./data2/Apache-0003-regression.csv     best      regression
# 6      ./data2/Apache-0004-classification.csv     best  classification
# 7          ./data2/Apache-0004-regression.csv     best      regression
# 8      ./data2/Apache-0005-classification.csv     best  classification
# 9          ./data2/Apache-0005-regression.csv     best      regression
# 10     ./data2/Apache-0006-classification.csv     best  classification
# 11         ./data2/Apache-0006-regression.csv     best      regression
# 12     ./data2/Apache-0007-classification.csv     best  classification
# 13         ./data2/Apache-0007-regression.csv     best      regression
# 14     ./data2/Apache-0008-classification.csv     best  classification
# 15         ./data2/Apache-0008-regression.csv     best      regression
# 16     ./data2/Apache-0009-classification.csv     best  classification
# 17         ./data2/Apache-0009-regression.csv     best      regression
# 18     ./data2/Apache-0010-classification.csv     best  classification
# 19         ./data2/Apache-0010-regression.csv     best      regression
# 20     ./data2/Apache-0011-classification.csv     best  classification
# 21         ./data2/Apache-0011-regression.csv     best      regression
# 22     ./data2/Apache-0012-classification.csv     best  classification
# 23         ./data2/Apache-0012-regression.csv     best      regression
# 24     ./data2/Apache-0013-classification.csv     best  classification
# 25         ./data2/Apache-0013-regression.csv     best      regression
# 26     ./data2/Apache-0014-classification.csv     best  classification
# 27         ./data2/Apache-0014-regression.csv     best      regression
# 28     ./data2/Apache-0015-classification.csv     best  classification
# 29         ./data2/Apache-0015-regression.csv     best      regression
# ...                                       ...      ...             ...
# 16170  ./data2/HIPAcc-1606-classification.csv     best  classification
# 16171      ./data2/HIPAcc-1606-regression.csv     best      regression
# 16172  ./data2/HIPAcc-1607-classification.csv     best  classification
# 16173      ./data2/HIPAcc-1607-regression.csv     best      regression
# 16174  ./data2/HIPAcc-1608-classification.csv     best  classification
# 16175      ./data2/HIPAcc-1608-regression.csv     best      regression
# 16176  ./data2/HIPAcc-1609-classification.csv     best  classification
# 16177      ./data2/HIPAcc-1609-regression.csv     best      regression
# 16178  ./data2/HIPAcc-1610-classification.csv     best  classification
# 16179      ./data2/HIPAcc-1610-regression.csv     best      regression
# 16180  ./data2/HIPAcc-1611-classification.csv     best  classification
# 16181      ./data2/HIPAcc-1611-regression.csv     best      regression
# 16182  ./data2/HIPAcc-1612-classification.csv     best  classification
# 16183      ./data2/HIPAcc-1612-regression.csv     best      regression
# 16184  ./data2/HIPAcc-1613-classification.csv     best  classification
# 16185      ./data2/HIPAcc-1613-regression.csv     best      regression
# 16186  ./data2/HIPAcc-1614-classification.csv     best  classification
# 16187      ./data2/HIPAcc-1614-regression.csv     best      regression
# 16188  ./data2/HIPAcc-1615-classification.csv     best  classification
# 16189      ./data2/HIPAcc-1615-regression.csv     best      regression
# 16190  ./data2/HIPAcc-1616-classification.csv     best  classification
# 16191      ./data2/HIPAcc-1616-regression.csv     best      regression
# 16192  ./data2/HIPAcc-1617-classification.csv     best  classification
# 16193      ./data2/HIPAcc-1617-regression.csv     best      regression
# 16194  ./data2/HIPAcc-1618-classification.csv     best  classification
# 16195      ./data2/HIPAcc-1618-regression.csv     best      regression
# 16196  ./data2/HIPAcc-1619-classification.csv     best  classification
# 16197      ./data2/HIPAcc-1619-regression.csv     best      regression
# 16198  ./data2/HIPAcc-1620-classification.csv     best  classification
# 16199      ./data2/HIPAcc-1620-regression.csv     best      regression
#
#        accuracy  precision    recall  specificity       npv
# 0      0.884415   0.877915  0.884279     0.884536  0.890771
# 1      0.884825   0.865238  0.901471     0.869274  0.905036
# 2      0.871930   0.887573  0.837344     0.904285  0.863432
# 3      0.886550   0.865096  0.908805     0.865773  0.909270
# 4      0.875526   0.889060  0.844045     0.904965  0.868597
# 5      0.878041   0.854483  0.904138     0.853658  0.903360
# 6      0.864883   0.879863  0.830546     0.896992  0.856659
# 7      0.872222   0.848753  0.902985     0.843467  0.899929
# 8      0.861696   0.871657  0.833148     0.888383  0.857990
# 9      0.862515   0.838747  0.893667     0.833383  0.890063
# 10     0.854064   0.862367  0.827587     0.878819  0.851577
# 11     0.857368   0.832571  0.893243     0.823826  0.887834
# 12     0.884152   0.881239  0.879554     0.888444  0.887176
# 13     0.891462   0.874716  0.904926     0.878891  0.908462
# 14     0.869883   0.895557  0.823523     0.913230  0.853122
# 15     0.893421   0.874333  0.914548     0.873675  0.914143
# 16     0.868304   0.881319  0.836840     0.897726  0.861903
# 17     0.887661   0.865356  0.912670     0.864289  0.911696
# 18     0.866696   0.879075  0.835996     0.895400  0.860549
# 19     0.874795   0.853466  0.900022     0.851217  0.899231
# 20     0.859152   0.866976  0.833648     0.883013  0.857185
# 21     0.867018   0.839945  0.902800     0.833561  0.898653
# 22     0.852193   0.863988  0.820085     0.882212  0.846832
# 23     0.851520   0.824444  0.891134     0.814487  0.885070
# 24     0.878012   0.874423  0.873812     0.881939  0.881625
# 25     0.887953   0.874659  0.896574     0.879912  0.901273
# 26     0.870731   0.896126  0.824621     0.913848  0.854130
# 27     0.889532   0.870320  0.908492     0.871827  0.909600
# 28     0.872485   0.887652  0.838609     0.904175  0.864216
# 29     0.887427   0.867348  0.907834     0.868352  0.908425
# ...         ...        ...       ...          ...       ...
# 16170  0.943826   0.962571  0.920075     0.967567  0.932718
# 16171  0.905080   0.905565  0.909982     0.900180  0.906682
# 16172  0.939771   0.957833  0.916701     0.962830  0.929302
# 16173  0.905015   0.905278  0.910137     0.899896  0.906880
# 16174  0.935684   0.952715  0.913680     0.957679  0.926186
# 16175  0.903556   0.904376  0.908703     0.898411  0.905030
# 16176  0.953932   0.960173  0.947225     0.960637  0.947888
# 16177  0.909933   0.914581  0.906269     0.913596  0.905725
# 16178  0.951946   0.970163  0.928878     0.975004  0.941350
# 16179  0.909633   0.913345  0.909455     0.909811  0.907340
# 16180  0.948939   0.967827  0.925130     0.972738  0.937693
# 16181  0.909418   0.913488  0.909317     0.909520  0.907015
# 16182  0.945291   0.964241  0.921389     0.969182  0.933987
# 16183  0.907976   0.911419  0.909691     0.906262  0.906585
# 16184  0.941020   0.959404  0.917625     0.964405  0.930256
# 16185  0.908719   0.912261  0.909236     0.908202  0.906854
# 16186  0.936685   0.953884  0.914559     0.958800  0.927034
# 16187  0.907036   0.910231  0.907321     0.906751  0.904868
# 16188  0.954976   0.961150  0.948410     0.961540  0.948995
# 16189  0.913866   0.919795  0.906654     0.921076  0.908114
# 16190  0.953234   0.971650  0.929974     0.976483  0.942457
# 16191  0.912743   0.915521  0.915662     0.909827  0.912350
# 16192  0.950094   0.968984  0.926314     0.973864  0.938846
# 16193  0.912300   0.915451  0.913056     0.911545  0.910389
# 16194  0.945951   0.965083  0.921862     0.970029  0.934484
# 16195  0.911769   0.915174  0.912700     0.910839  0.909861
# 16196  0.942092   0.960636  0.918562     0.965612  0.931176
# 16197  0.911246   0.914379  0.912896     0.909598  0.909873
# 16198  0.937367   0.954682  0.915099     0.959625  0.927609
# 16199  0.911335   0.913093  0.914378     0.908294  0.911414
#
# [16200 rows x 20 columns]

# %% [markdown]
# Show best accuracy results for each filefor classification and regression

# %%
metric = "accuracy"
idx = resultsList.groupby(["file","type"])[metric].transform(max) == resultsList[metric]
resultsList[(resultsList['type'] == "classification") | (resultsList['type'] == "regression")][idx].sort_values(["file"])
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#        class_weight criterion       file  max_depth  max_features  \
# 11617           NaN       mae     Apache       70.0           NaN
# 11664           NaN      gini     Apache       80.0           NaN
# 1597            NaN       mse  BerkeleyC       40.0           NaN
# 12672           NaN      gini  BerkeleyC       70.0           NaN
# 3228            NaN   entropy  BerkeleyJ       90.0           NaN
# 13177           NaN       mae  BerkeleyJ       20.0           NaN
# 3445            NaN       mse       Dune       10.0           NaN
# 14556           NaN      gini       Dune       40.0           NaN
# 4416            NaN   entropy     HIPAcc        NaN           NaN
# 15435           NaN       mae     HIPAcc       20.0           NaN
#
#        max_leaf_nodes  min_impurity_decrease  min_samples_leaf  \
# 11617              60           1.000000e-07                 1
# 11664              10           1.000000e-07                 1
# 1597               80           1.000000e-07                 1
# 12672              40           1.000000e-07                 1
# 3228               90           1.000000e-07                 1
# 13177              10           1.000000e-07                 1
# 3445               90           1.000000e-07                 1
# 14556              80           1.000000e-07                 1
# 4416               90           1.000000e-07                 1
# 15435              90           1.000000e-07                 2
#
#        min_samples_split  min_weight_fraction_leaf  presort  random_state  \
# 11617                  2                       0.0    False           NaN
# 11664                  2                       0.0    False           NaN
# 1597                   2                       0.0    False           NaN
# 12672                  2                       0.0    False           NaN
# 3228                   2                       0.0    False           NaN
# 13177                  2                       0.0    False           NaN
# 3445                   2                       0.0    False           NaN
# 14556                  2                       0.0    False           NaN
# 4416                   2                       0.0    False           NaN
# 15435                  2                       0.0    False           NaN
#
#                                          results splitter            type  \
# 11617         ./data2/Apache-1489-regression.csv     best      regression
# 11664     ./data2/Apache-1513-classification.csv     best  classification
# 1597       ./data2/BerkeleyC-0259-regression.csv     best      regression
# 12672  ./data2/BerkeleyC-1477-classification.csv     best  classification
# 3228   ./data2/BerkeleyJ-0535-classification.csv     best  classification
# 13177      ./data2/BerkeleyJ-1189-regression.csv     best      regression
# 3445            ./data2/Dune-0103-regression.csv     best      regression
# 14556       ./data2/Dune-1339-classification.csv     best  classification
# 4416      ./data2/HIPAcc-0049-classification.csv     best  classification
# 15435         ./data2/HIPAcc-1238-regression.csv     best      regression
#
#        accuracy  precision    recall  specificity       npv
# 11617  0.896930   0.892587  0.894517     0.899191  0.901198
# 11664  0.889123   0.886975  0.883748     0.894152  0.891342
# 1597   0.982767   0.981991  0.983963     0.981571  0.983561
# 12672  0.980288   0.981257  0.978671     0.981904  0.979358
# 3228   0.919204   0.918366  0.917899     0.920473  0.920161
# 13177  0.931550   0.931488  0.930210     0.932846  0.931763
# 3445   0.895134   0.894358  0.895843     0.894426  0.895941
# 14556  0.920172   0.920258  0.919756     0.920587  0.920107
# 4416   0.957145   0.964573  0.949556     0.964731  0.950002
# 15435  0.913886   0.917265  0.913164     0.914608  0.911526

# %% [markdown]
# Show 10 best configurations for Apache considering accuracy

# %%
metric = "accuracy"
resultsList[(resultsList['file'] == "Apache") & ((resultsList['type'] == "classification") | (resultsList['type'] == "regression"))].sort_values(metric,  ascending=False)[:10]
# Out:
#        class_weight criterion    file  max_depth  max_features  \
# 11617           NaN       mae  Apache       70.0           NaN
# 10957           NaN       mae  Apache       10.0           NaN
# 11653           NaN       mae  Apache       70.0           NaN
# 11113           NaN       mae  Apache       20.0           NaN
# 11065           NaN       mae  Apache       20.0           NaN
# 11485           NaN       mae  Apache       60.0           NaN
# 11005           NaN       mae  Apache       10.0           NaN
# 625             NaN       mse  Apache       50.0           NaN
# 11571           NaN       mae  Apache       70.0           NaN
# 10837           NaN       mae  Apache        NaN           NaN
#
#        max_leaf_nodes  min_impurity_decrease  min_samples_leaf  \
# 11617              60           1.000000e-07                 1
# 10957              50           1.000000e-07                 1
# 11653              90           1.000000e-07                 1
# 11113              90           1.000000e-07                 1
# 11065              50           1.000000e-07                 1
# 11485              40           1.000000e-07                 1
# 11005              90           1.000000e-07                 1
# 625                80           1.000000e-07                 1
# 11571              20           1.000000e-07                 2
# 10837              40           1.000000e-07                 1
#
#        min_samples_split  min_weight_fraction_leaf  presort  random_state  \
# 11617                  2                       0.0    False           NaN
# 10957                  2                       0.0    False           NaN
# 11653                  2                       0.0    False           NaN
# 11113                  2                       0.0    False           NaN
# 11065                  2                       0.0    False           NaN
# 11485                  2                       0.0    False           NaN
# 11005                  2                       0.0    False           NaN
# 625                    2                       0.0    False           NaN
# 11571                  2                       0.0    False           NaN
# 10837                  2                       0.0    False           NaN
#
#                                   results splitter        type  accuracy  \
# 11617  ./data2/Apache-1489-regression.csv     best  regression  0.896930
# 10957  ./data2/Apache-1159-regression.csv     best  regression  0.896784
# 11653  ./data2/Apache-1507-regression.csv     best  regression  0.896696
# 11113  ./data2/Apache-1237-regression.csv     best  regression  0.896579
# 11065  ./data2/Apache-1213-regression.csv     best  regression  0.896491
# 11485  ./data2/Apache-1423-regression.csv     best  regression  0.896433
# 11005  ./data2/Apache-1183-regression.csv     best  regression  0.896404
# 625    ./data2/Apache-0313-regression.csv     best  regression  0.896374
# 11571  ./data2/Apache-1466-regression.csv     best  regression  0.896287
# 10837  ./data2/Apache-1099-regression.csv     best  regression  0.895936
#
#        precision    recall  specificity       npv
# 11617   0.892587  0.894517     0.899191  0.901198
# 10957   0.891734  0.896027     0.897496  0.901858
# 11653   0.895136  0.891175     0.901848  0.898529
# 11113   0.892211  0.894991     0.898051  0.901107
# 11065   0.890606  0.896327     0.896644  0.902296
# 11485   0.888095  0.899045     0.893991  0.904704
# 11005   0.893904  0.892268     0.900269  0.898887
# 625     0.891315  0.895420     0.897279  0.901368
# 11571   0.886933  0.906731     0.886519  0.908019
# 10837   0.890899  0.895298     0.896530  0.900995

# %% [markdown]
# Show 10 best classification configurations considering accuracy

# %%
metric = "accuracy"
resultsList[(resultsList['file'] == "Apache") & (resultsList['type'] == "classification")].sort_values(metric,  ascending=False)[:10]
# Out:
#        class_weight criterion    file  max_depth  max_features  \
# 11664           NaN      gini  Apache       80.0           NaN
# 11340           NaN      gini  Apache       50.0           NaN
# 10800           NaN      gini  Apache        NaN           NaN
# 11016           NaN      gini  Apache       20.0           NaN
# 11556           NaN      gini  Apache       70.0           NaN
# 11232           NaN      gini  Apache       40.0           NaN
# 432             NaN   entropy  Apache       40.0           NaN
# 11124           NaN      gini  Apache       30.0           NaN
# 864             NaN   entropy  Apache       80.0           NaN
# 324             NaN   entropy  Apache       30.0           NaN
#
#        max_leaf_nodes  min_impurity_decrease  min_samples_leaf  \
# 11664              10           1.000000e-07                 1
# 11340              10           1.000000e-07                 1
# 10800              10           1.000000e-07                 1
# 11016              10           1.000000e-07                 1
# 11556              10           1.000000e-07                 1
# 11232              10           1.000000e-07                 1
# 432                10           1.000000e-07                 1
# 11124              10           1.000000e-07                 1
# 864                10           1.000000e-07                 1
# 324                10           1.000000e-07                 1
#
#        min_samples_split  min_weight_fraction_leaf  presort  random_state  \
# 11664                  2                       0.0    False           NaN
# 11340                  2                       0.0    False           NaN
# 10800                  2                       0.0    False           NaN
# 11016                  2                       0.0    False           NaN
# 11556                  2                       0.0    False           NaN
# 11232                  2                       0.0    False           NaN
# 432                    2                       0.0    False           NaN
# 11124                  2                       0.0    False           NaN
# 864                    2                       0.0    False           NaN
# 324                    2                       0.0    False           NaN
#
#                                       results splitter            type  \
# 11664  ./data2/Apache-1513-classification.csv     best  classification
# 11340  ./data2/Apache-1351-classification.csv     best  classification
# 10800  ./data2/Apache-1081-classification.csv     best  classification
# 11016  ./data2/Apache-1189-classification.csv     best  classification
# 11556  ./data2/Apache-1459-classification.csv     best  classification
# 11232  ./data2/Apache-1297-classification.csv     best  classification
# 432    ./data2/Apache-0217-classification.csv     best  classification
# 11124  ./data2/Apache-1243-classification.csv     best  classification
# 864    ./data2/Apache-0433-classification.csv     best  classification
# 324    ./data2/Apache-0163-classification.csv     best  classification
#
#        accuracy  precision    recall  specificity       npv
# 11664  0.889123   0.886975  0.883748     0.894152  0.891342
# 11340  0.887193   0.884066  0.883202     0.890918  0.890397
# 10800  0.887164   0.884852  0.881919     0.892058  0.889564
# 11016  0.886813   0.882581  0.883324     0.890078  0.890918
# 11556  0.886491   0.883537  0.881793     0.890865  0.889436
# 11232  0.886433   0.886955  0.877984     0.894317  0.886291
# 432    0.885848   0.884706  0.878657     0.892563  0.887145
# 11124  0.885760   0.882508  0.881196     0.890023  0.889096
# 864    0.885731   0.882301  0.881258     0.889905  0.889130
# 324    0.885263   0.883818  0.878663     0.891438  0.886823
