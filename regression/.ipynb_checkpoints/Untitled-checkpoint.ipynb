# %%
import pandas as pd

# %%
df = pd.read_csv("./data2/Apache-0001-classification.csv")

# %%
df
# Out:
#       FN   FP    TN    TP   sr     t
# 0    0.0  3.0   0.0  17.0    2   960
# 1    0.0  5.0   0.0  15.0    2  1020
# 2    6.0  2.3   3.7   8.0    2  1080
# 3    5.6  3.4   4.6   6.4    2  1140
# 4    3.3  4.6   6.4   5.7    2  1230
# 5    3.9  4.8   7.2   4.1    2  1320
# 6    2.1  6.9   7.1   3.9    2  1770
# 7    4.0  0.0  16.0   0.0    2  1980
# 8    2.0  0.0  18.0   0.0    2  2160
# 9    3.6  1.7   1.3  13.4   11   960
# 10   4.0  1.1   3.9  11.0   11  1020
# 11   2.5  2.7   3.3  11.5   11  1080
# 12   1.7  3.0   5.0  10.3   11  1140
# 13   2.3  2.5   8.5   6.7   11  1230
# 14   1.7  1.5  10.5   6.3   11  1320
# 15   0.8  3.1  10.9   5.2   11  1770
# 16   1.4  1.9  14.1   2.6   11  1980
# 17   1.2  3.5  14.5   0.8   11  2160
# 18   1.6  0.8   2.2  15.4   20   960
# 19   1.5  0.8   4.2  13.5   20  1020
# 20   2.0  2.2   3.8  12.0   20  1080
# 21   2.6  2.1   5.9   9.4   20  1140
# 22   1.1  1.9   9.1   7.9   20  1230
# 23   0.8  2.8   9.2   7.2   20  1320
# 24   0.3  1.4  12.6   5.7   20  1770
# 25   1.4  1.9  14.1   2.6   20  1980
# 26   1.0  1.8  16.2   1.0   20  2160
# 27   2.2  1.2   1.8  14.8   29   960
# 28   1.9  2.3   2.7  13.1   29  1020
# 29   2.0  2.0   4.0  12.0   29  1080
# ..   ...  ...   ...   ...  ...   ...
# 141  0.5  0.5  13.5   5.5  137  1770
# 142  1.0  0.2  15.8   3.0  137  1980
# 143  0.7  0.5  17.5   1.3  137  2160
# 144  0.8  0.7   2.3  16.2  146   960
# 145  0.4  1.2   3.8  14.6  146  1020
# 146  1.0  0.8   5.2  13.0  146  1080
# 147  1.0  1.9   6.1  11.0  146  1140
# 148  1.7  0.4  10.6   7.3  146  1230
# 149  0.8  0.7  11.3   7.2  146  1320
# 150  0.7  0.2  13.8   5.3  146  1770
# 151  0.5  0.6  16.4   2.5  146  1980
# 152  0.5  0.6  17.4   1.5  146  2160
# 153  0.6  0.2   2.8  16.4  155   960
# 154  0.6  0.7   4.3  14.4  155  1020
# 155  0.4  1.1   4.9  13.6  155  1080
# 156  0.6  1.6   6.4  11.4  155  1140
# 157  1.3  0.0  11.0   7.7  155  1230
# 158  0.4  0.0  12.0   7.6  155  1320
# 159  0.4  0.2  13.8   5.6  155  1770
# 160  0.6  0.2  15.8   3.4  155  1980
# 161  0.8  1.4  16.6   1.2  155  2160
# 162  0.4  1.0   2.0  16.6  164   960
# 163  0.3  1.5   3.5  14.7  164  1020
# 164  0.4  1.0   5.0  13.6  164  1080
# 165  1.0  1.1   6.9  11.0  164  1140
# 166  1.2  0.2  10.8   7.8  164  1230
# 167  0.7  0.1  11.9   7.3  164  1320
# 168  0.1  0.9  13.1   5.9  164  1770
# 169  0.6  1.1  14.9   3.4  164  1980
# 170  0.5  0.5  17.5   1.5  164  2160
#
# [171 rows x 6 columns]

# %%
dfMean = df.groupby(['sr']).mean().drop(['t'],axis=1)

# %%
dfMean
# Out:
#            FN        FP        TN        TP  accuracy
# sr
# 2    2.988889  3.333333  7.000000  6.677778  0.683889
# 11   2.133333  2.333333  8.000000  7.533333  0.776667
# 20   1.366667  1.744444  8.588889  8.300000  0.844444
# 29   1.522222  1.244444  9.088889  8.144444  0.861667
# 38   1.377778  1.288889  9.044444  8.288889  0.866667
# 47   1.122222  1.188889  9.144444  8.544444  0.884444
# 56   1.155556  1.188889  9.144444  8.511111  0.882778
# 65   0.877778  0.922222  9.411111  8.788889  0.910000
# 74   0.922222  0.922222  9.411111  8.744444  0.907778
# 83   0.966667  0.955556  9.377778  8.700000  0.903889
# 92   0.822222  0.911111  9.422222  8.844444  0.913333
# 101  0.844444  0.866667  9.466667  8.822222  0.914444
# 110  0.844444  0.844444  9.488889  8.822222  0.915556
# 119  0.677778  0.977778  9.355556  8.988889  0.917222
# 128  0.777778  0.933333  9.400000  8.888889  0.914444
# 137  0.811111  0.811111  9.522222  8.855556  0.918889
# 146  0.822222  0.788889  9.655556  8.733333  0.919444
# 155  0.633333  0.600000  9.733333  9.033333  0.938333
# 164  0.577778  0.822222  9.511111  9.088889  0.930000

# %%
dfMean['accuracy']= (dfMean['TP']+dfMean['TN']) / (dfMean['TP']+dfMean['TN']+dfMean['FN']+dfMean['FP'])

# %%
dfMean['accuracy'].mean()
# Out:
# 0.8844152046783625

# %%
resultsList = pd.read_csv("./data2/results-list.csv")

# %%
resultsList['results'][1].split("-")[2].split(".")[0]
# Out:
# 'regression'

# %%
serie = []
for i in resultsList['results']:
    serie.append(i.split("-")[2].split(".")[0])
#print(serie)

serie = pd.Series(serie)

resultsList['type'] = serie

# %%
resultsList
# Out:
#        class_weight criterion    file  max_depth  max_features  \
# 0               NaN   entropy  Apache        NaN           NaN
# 1               NaN       mse  Apache        NaN           NaN
# 2               NaN   entropy  Apache        NaN           NaN
# 3               NaN       mse  Apache        NaN           NaN
# 4               NaN   entropy  Apache        NaN           NaN
# 5               NaN       mse  Apache        NaN           NaN
# 6               NaN   entropy  Apache        NaN           NaN
# 7               NaN       mse  Apache        NaN           NaN
# 8               NaN   entropy  Apache        NaN           NaN
# 9               NaN       mse  Apache        NaN           NaN
# 10              NaN   entropy  Apache        NaN           NaN
# 11              NaN       mse  Apache        NaN           NaN
# 12              NaN   entropy  Apache        NaN           NaN
# 13              NaN       mse  Apache        NaN           NaN
# 14              NaN   entropy  Apache        NaN           NaN
# 15              NaN       mse  Apache        NaN           NaN
# 16              NaN   entropy  Apache        NaN           NaN
# 17              NaN       mse  Apache        NaN           NaN
# 18              NaN   entropy  Apache        NaN           NaN
# 19              NaN       mse  Apache        NaN           NaN
# 20              NaN   entropy  Apache        NaN           NaN
# 21              NaN       mse  Apache        NaN           NaN
# 22              NaN   entropy  Apache        NaN           NaN
# 23              NaN       mse  Apache        NaN           NaN
# 24              NaN   entropy  Apache        NaN           NaN
# 25              NaN       mse  Apache        NaN           NaN
# 26              NaN   entropy  Apache        NaN           NaN
# 27              NaN       mse  Apache        NaN           NaN
# 28              NaN   entropy  Apache        NaN           NaN
# 29              NaN       mse  Apache        NaN           NaN
# ...             ...       ...     ...        ...           ...
# 10770           NaN   entropy  HIPAcc       90.0           NaN
# 10771           NaN   entropy  HIPAcc       90.0           NaN
# 10772           NaN   entropy  HIPAcc       90.0           NaN
# 10773           NaN   entropy  HIPAcc       90.0           NaN
# 10774           NaN   entropy  HIPAcc       90.0           NaN
# 10775           NaN   entropy  HIPAcc       90.0           NaN
# 10776           NaN   entropy  HIPAcc       90.0           NaN
# 10777           NaN   entropy  HIPAcc       90.0           NaN
# 10778           NaN   entropy  HIPAcc       90.0           NaN
# 10779           NaN   entropy  HIPAcc       90.0           NaN
# 10780           NaN   entropy  HIPAcc       90.0           NaN
# 10781           NaN   entropy  HIPAcc       90.0           NaN
# 10782           NaN   entropy  HIPAcc       90.0           NaN
# 10783           NaN   entropy  HIPAcc       90.0           NaN
# 10784           NaN   entropy  HIPAcc       90.0           NaN
# 10785           NaN   entropy  HIPAcc       90.0           NaN
# 10786           NaN   entropy  HIPAcc       90.0           NaN
# 10787           NaN   entropy  HIPAcc       90.0           NaN
# 10788           NaN   entropy  HIPAcc       90.0           NaN
# 10789           NaN   entropy  HIPAcc       90.0           NaN
# 10790           NaN   entropy  HIPAcc       90.0           NaN
# 10791           NaN   entropy  HIPAcc       90.0           NaN
# 10792           NaN   entropy  HIPAcc       90.0           NaN
# 10793           NaN   entropy  HIPAcc       90.0           NaN
# 10794           NaN   entropy  HIPAcc       90.0           NaN
# 10795           NaN   entropy  HIPAcc       90.0           NaN
# 10796           NaN   entropy  HIPAcc       90.0           NaN
# 10797           NaN   entropy  HIPAcc       90.0           NaN
# 10798           NaN   entropy  HIPAcc       90.0           NaN
# 10799           NaN   entropy  HIPAcc       90.0           NaN
#
#        max_leaf_nodes  min_impurity_decrease  min_samples_leaf  \
# 0                  10           1.000000e-07                 1
# 1                  10           1.000000e-07                 1
# 2                  10           1.000000e-07                 2
# 3                  10           1.000000e-07                 2
# 4                  10           1.000000e-07                 4
# 5                  10           1.000000e-07                 4
# 6                  10           1.000000e-07                 6
# 7                  10           1.000000e-07                 6
# 8                  10           1.000000e-07                 8
# 9                  10           1.000000e-07                 8
# 10                 10           1.000000e-07                10
# 11                 10           1.000000e-07                10
# 12                 20           1.000000e-07                 1
# 13                 20           1.000000e-07                 1
# 14                 20           1.000000e-07                 2
# 15                 20           1.000000e-07                 2
# 16                 20           1.000000e-07                 4
# 17                 20           1.000000e-07                 4
# 18                 20           1.000000e-07                 6
# 19                 20           1.000000e-07                 6
# 20                 20           1.000000e-07                 8
# 21                 20           1.000000e-07                 8
# 22                 20           1.000000e-07                10
# 23                 20           1.000000e-07                10
# 24                 30           1.000000e-07                 1
# 25                 30           1.000000e-07                 1
# 26                 30           1.000000e-07                 2
# 27                 30           1.000000e-07                 2
# 28                 30           1.000000e-07                 4
# 29                 30           1.000000e-07                 4
# ...               ...                    ...               ...
# 10770              70           1.000000e-07                 6
# 10771              70           1.000000e-07                 6
# 10772              70           1.000000e-07                 8
# 10773              70           1.000000e-07                 8
# 10774              70           1.000000e-07                10
# 10775              70           1.000000e-07                10
# 10776              80           1.000000e-07                 1
# 10777              80           1.000000e-07                 1
# 10778              80           1.000000e-07                 2
# 10779              80           1.000000e-07                 2
# 10780              80           1.000000e-07                 4
# 10781              80           1.000000e-07                 4
# 10782              80           1.000000e-07                 6
# 10783              80           1.000000e-07                 6
# 10784              80           1.000000e-07                 8
# 10785              80           1.000000e-07                 8
# 10786              80           1.000000e-07                10
# 10787              80           1.000000e-07                10
# 10788              90           1.000000e-07                 1
# 10789              90           1.000000e-07                 1
# 10790              90           1.000000e-07                 2
# 10791              90           1.000000e-07                 2
# 10792              90           1.000000e-07                 4
# 10793              90           1.000000e-07                 4
# 10794              90           1.000000e-07                 6
# 10795              90           1.000000e-07                 6
# 10796              90           1.000000e-07                 8
# 10797              90           1.000000e-07                 8
# 10798              90           1.000000e-07                10
# 10799              90           1.000000e-07                10
#
#        min_samples_split  min_weight_fraction_leaf  presort  random_state  \
# 0                      2                       0.0    False           NaN
# 1                      2                       0.0    False           NaN
# 2                      2                       0.0    False           NaN
# 3                      2                       0.0    False           NaN
# 4                      2                       0.0    False           NaN
# 5                      2                       0.0    False           NaN
# 6                      2                       0.0    False           NaN
# 7                      2                       0.0    False           NaN
# 8                      2                       0.0    False           NaN
# 9                      2                       0.0    False           NaN
# 10                     2                       0.0    False           NaN
# 11                     2                       0.0    False           NaN
# 12                     2                       0.0    False           NaN
# 13                     2                       0.0    False           NaN
# 14                     2                       0.0    False           NaN
# 15                     2                       0.0    False           NaN
# 16                     2                       0.0    False           NaN
# 17                     2                       0.0    False           NaN
# 18                     2                       0.0    False           NaN
# 19                     2                       0.0    False           NaN
# 20                     2                       0.0    False           NaN
# 21                     2                       0.0    False           NaN
# 22                     2                       0.0    False           NaN
# 23                     2                       0.0    False           NaN
# 24                     2                       0.0    False           NaN
# 25                     2                       0.0    False           NaN
# 26                     2                       0.0    False           NaN
# 27                     2                       0.0    False           NaN
# 28                     2                       0.0    False           NaN
# 29                     2                       0.0    False           NaN
# ...                  ...                       ...      ...           ...
# 10770                  2                       0.0    False           NaN
# 10771                  2                       0.0    False           NaN
# 10772                  2                       0.0    False           NaN
# 10773                  2                       0.0    False           NaN
# 10774                  2                       0.0    False           NaN
# 10775                  2                       0.0    False           NaN
# 10776                  2                       0.0    False           NaN
# 10777                  2                       0.0    False           NaN
# 10778                  2                       0.0    False           NaN
# 10779                  2                       0.0    False           NaN
# 10780                  2                       0.0    False           NaN
# 10781                  2                       0.0    False           NaN
# 10782                  2                       0.0    False           NaN
# 10783                  2                       0.0    False           NaN
# 10784                  2                       0.0    False           NaN
# 10785                  2                       0.0    False           NaN
# 10786                  2                       0.0    False           NaN
# 10787                  2                       0.0    False           NaN
# 10788                  2                       0.0    False           NaN
# 10789                  2                       0.0    False           NaN
# 10790                  2                       0.0    False           NaN
# 10791                  2                       0.0    False           NaN
# 10792                  2                       0.0    False           NaN
# 10793                  2                       0.0    False           NaN
# 10794                  2                       0.0    False           NaN
# 10795                  2                       0.0    False           NaN
# 10796                  2                       0.0    False           NaN
# 10797                  2                       0.0    False           NaN
# 10798                  2                       0.0    False           NaN
# 10799                  2                       0.0    False           NaN
#
#                                               results splitter  \
# 0              ./data2/Apache-0001-classification.csv     best
# 1                  ./data2/Apache-0001-regression.csv     best
# 2              ./data2/Apache-0002-classification.csv     best
# 3                  ./data2/Apache-0002-regression.csv     best
# 4              ./data2/Apache-0003-classification.csv     best
# 5                  ./data2/Apache-0003-regression.csv     best
# 6              ./data2/Apache-0004-classification.csv     best
# 7                  ./data2/Apache-0004-regression.csv     best
# 8              ./data2/Apache-0005-classification.csv     best
# 9                  ./data2/Apache-0005-regression.csv     best
# 10             ./data2/Apache-0006-classification.csv     best
# 11                 ./data2/Apache-0006-regression.csv     best
# 12             ./data2/Apache-0007-classification.csv     best
# 13                 ./data2/Apache-0007-regression.csv     best
# 14             ./data2/Apache-0008-classification.csv     best
# 15                 ./data2/Apache-0008-regression.csv     best
# 16             ./data2/Apache-0009-classification.csv     best
# 17                 ./data2/Apache-0009-regression.csv     best
# 18             ./data2/Apache-0010-classification.csv     best
# 19                 ./data2/Apache-0010-regression.csv     best
# 20             ./data2/Apache-0011-classification.csv     best
# 21                 ./data2/Apache-0011-regression.csv     best
# 22             ./data2/Apache-0012-classification.csv     best
# 23                 ./data2/Apache-0012-regression.csv     best
# 24             ./data2/Apache-0013-classification.csv     best
# 25                 ./data2/Apache-0013-regression.csv     best
# 26             ./data2/Apache-0014-classification.csv     best
# 27                 ./data2/Apache-0014-regression.csv     best
# 28             ./data2/Apache-0015-classification.csv     best
# 29                 ./data2/Apache-0015-regression.csv     best
# ...                                               ...      ...
# 10770  ./data2/HIPAcc-1066-classification_strat_6.csv     best
# 10771  ./data2/HIPAcc-1066-classification_strat_8.csv     best
# 10772  ./data2/HIPAcc-1067-classification_strat_6.csv     best
# 10773  ./data2/HIPAcc-1067-classification_strat_8.csv     best
# 10774  ./data2/HIPAcc-1068-classification_strat_6.csv     best
# 10775  ./data2/HIPAcc-1068-classification_strat_8.csv     best
# 10776  ./data2/HIPAcc-1069-classification_strat_6.csv     best
# 10777  ./data2/HIPAcc-1069-classification_strat_8.csv     best
# 10778  ./data2/HIPAcc-1070-classification_strat_6.csv     best
# 10779  ./data2/HIPAcc-1070-classification_strat_8.csv     best
# 10780  ./data2/HIPAcc-1071-classification_strat_6.csv     best
# 10781  ./data2/HIPAcc-1071-classification_strat_8.csv     best
# 10782  ./data2/HIPAcc-1072-classification_strat_6.csv     best
# 10783  ./data2/HIPAcc-1072-classification_strat_8.csv     best
# 10784  ./data2/HIPAcc-1073-classification_strat_6.csv     best
# 10785  ./data2/HIPAcc-1073-classification_strat_8.csv     best
# 10786  ./data2/HIPAcc-1074-classification_strat_6.csv     best
# 10787  ./data2/HIPAcc-1074-classification_strat_8.csv     best
# 10788  ./data2/HIPAcc-1075-classification_strat_6.csv     best
# 10789  ./data2/HIPAcc-1075-classification_strat_8.csv     best
# 10790  ./data2/HIPAcc-1076-classification_strat_6.csv     best
# 10791  ./data2/HIPAcc-1076-classification_strat_8.csv     best
# 10792  ./data2/HIPAcc-1077-classification_strat_6.csv     best
# 10793  ./data2/HIPAcc-1077-classification_strat_8.csv     best
# 10794  ./data2/HIPAcc-1078-classification_strat_6.csv     best
# 10795  ./data2/HIPAcc-1078-classification_strat_8.csv     best
# 10796  ./data2/HIPAcc-1079-classification_strat_6.csv     best
# 10797  ./data2/HIPAcc-1079-classification_strat_8.csv     best
# 10798  ./data2/HIPAcc-1080-classification_strat_6.csv     best
# 10799  ./data2/HIPAcc-1080-classification_strat_8.csv     best
#
#                          type
# 0              classification
# 1                  regression
# 2              classification
# 3                  regression
# 4              classification
# 5                  regression
# 6              classification
# 7                  regression
# 8              classification
# 9                  regression
# 10             classification
# 11                 regression
# 12             classification
# 13                 regression
# 14             classification
# 15                 regression
# 16             classification
# 17                 regression
# 18             classification
# 19                 regression
# 20             classification
# 21                 regression
# 22             classification
# 23                 regression
# 24             classification
# 25                 regression
# 26             classification
# 27                 regression
# 28             classification
# 29                 regression
# ...                       ...
# 10770  classification_strat_6
# 10771  classification_strat_8
# 10772  classification_strat_6
# 10773  classification_strat_8
# 10774  classification_strat_6
# 10775  classification_strat_8
# 10776  classification_strat_6
# 10777  classification_strat_8
# 10778  classification_strat_6
# 10779  classification_strat_8
# 10780  classification_strat_6
# 10781  classification_strat_8
# 10782  classification_strat_6
# 10783  classification_strat_8
# 10784  classification_strat_6
# 10785  classification_strat_8
# 10786  classification_strat_6
# 10787  classification_strat_8
# 10788  classification_strat_6
# 10789  classification_strat_8
# 10790  classification_strat_6
# 10791  classification_strat_8
# 10792  classification_strat_6
# 10793  classification_strat_8
# 10794  classification_strat_6
# 10795  classification_strat_8
# 10796  classification_strat_6
# 10797  classification_strat_8
# 10798  classification_strat_6
# 10799  classification_strat_8
#
# [10800 rows x 15 columns]

# %%
accuracy = []
for i in resultsList['results']:
    dfTemp = pd.read_csv(i)
    dfMean = dfTemp.groupby(['sr']).mean().drop(['t'],axis=1)
    dfMean['accuracy']= (dfMean['TP']+dfMean['TN']) / (dfMean['TP']+dfMean['TN']+dfMean['FN']+dfMean['FP'])
    accuracy.append(dfMean['accuracy'].mean())
resultsList['accuracy'] = pd.Series(accuracy)

idx = resultsList.groupby(["file","type"])["accuracy"].transform(max) == resultsList['accuracy']
resultsList[idx].sort_values(["file"])

# %%
dfLast = resultsList[idx].sort_values(["file","type"])[["accuracy","type","file"]]

# %%
dfLast.style.apply(highlight_max, maxValues=idx2[idx2 == True].index.values, axis=1)
# Out:
# [5568 6306 6619 7284 4416]
# 432
# ['']
# [5568 6306 6619 7284 4416]
# 432
# ['']
# [5568 6306 6619 7284 4416]
# 5736
# ['']
# [5568 6306 6619 7284 4416]
# 5749
# ['']
# [5568 6306 6619 7284 4416]
# 625
# ['']
# [5568 6306 6619 7284 4416]
# 1776
# ['']
# [5568 6306 6619 7284 4416]
# 7536
# ['']
# [5568 6306 6619 7284 4416]
# 7537
# ['']
# [5568 6306 6619 7284 4416]
# 1597
# ['']
# [5568 6306 6619 7284 4416]
# 3228
# ['']
# [5568 6306 6619 7284 4416]
# 7682
# ['']
# [5568 6306 6619 7284 4416]
# 7563
# ['']
# [5568 6306 6619 7284 4416]
# 2173
# ['']
# [5568 6306 6619 7284 4416]
# 3984
# ['']
# [5568 6306 6619 7284 4416]
# 9060
# ['']
# [5568 6306 6619 7284 4416]
# 9493
# ['']
# [5568 6306 6619 7284 4416]
# 3445
# ['']
# [5568 6306 6619 7284 4416]
# 4416
# ['background-color: yellow']
# [5568 6306 6619 7284 4416]
# 10140
# ['']
# [5568 6306 6619 7284 4416]
# 10249
# ['']
# [5568 6306 6619 7284 4416]
# 4849
# ['']
# <style  type="text/css" >
#     #T_ae64a168_207e_11e8_93c2_64006a775debrow16_col0 {
#             background-color:  yellow;
#         }    #T_ae64a168_207e_11e8_93c2_64006a775debrow16_col1 {
#             background-color:  yellow;
#         }    #T_ae64a168_207e_11e8_93c2_64006a775debrow16_col2 {
#             background-color:  yellow;
#         }</style>
# <table id="T_ae64a168_207e_11e8_93c2_64006a775deb" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >accuracy</th>
#         <th class="col_heading level0 col1" >type</th>
#         <th class="col_heading level0 col2" >file</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row0" class="row_heading level0 row0" >432</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow0_col0" class="data row0 col0" >0.885848</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow0_col1" class="data row0 col1" >classification</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow0_col2" class="data row0 col2" >Apache</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row1" class="row_heading level0 row1" >5736</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow1_col0" class="data row1 col0" >0.90216</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow1_col1" class="data row1 col1" >classification_strat_6</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow1_col2" class="data row1 col2" >Apache</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row2" class="row_heading level0 row2" >5749</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow2_col0" class="data row2 col0" >0.9025</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow2_col1" class="data row2 col1" >classification_strat_8</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow2_col2" class="data row2 col2" >Apache</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row3" class="row_heading level0 row3" >625</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow3_col0" class="data row3 col0" >0.896374</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow3_col1" class="data row3 col1" >regression</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow3_col2" class="data row3 col2" >Apache</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row4" class="row_heading level0 row4" >1776</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow4_col0" class="data row4 col0" >0.980032</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow4_col1" class="data row4 col1" >classification</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow4_col2" class="data row4 col2" >BerkeleyC</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row5" class="row_heading level0 row5" >7536</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow5_col0" class="data row5 col0" >0.991981</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow5_col1" class="data row5 col1" >classification_strat_6</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow5_col2" class="data row5 col2" >BerkeleyC</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row6" class="row_heading level0 row6" >7537</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow6_col0" class="data row6 col0" >0.991769</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow6_col1" class="data row6 col1" >classification_strat_8</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow6_col2" class="data row6 col2" >BerkeleyC</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row7" class="row_heading level0 row7" >1597</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow7_col0" class="data row7 col0" >0.982767</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow7_col1" class="data row7 col1" >regression</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow7_col2" class="data row7 col2" >BerkeleyC</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row8" class="row_heading level0 row8" >3228</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow8_col0" class="data row8 col0" >0.919204</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow8_col1" class="data row8 col1" >classification</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow8_col2" class="data row8 col2" >BerkeleyJ</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row9" class="row_heading level0 row9" >7682</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow9_col0" class="data row9 col0" >0.94045</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow9_col1" class="data row9 col1" >classification_strat_6</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow9_col2" class="data row9 col2" >BerkeleyJ</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row10" class="row_heading level0 row10" >7563</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow10_col0" class="data row10 col0" >0.941685</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow10_col1" class="data row10 col1" >classification_strat_8</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow10_col2" class="data row10 col2" >BerkeleyJ</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row11" class="row_heading level0 row11" >2173</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow11_col0" class="data row11 col0" >0.930007</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow11_col1" class="data row11 col1" >regression</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow11_col2" class="data row11 col2" >BerkeleyJ</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row12" class="row_heading level0 row12" >3984</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow12_col0" class="data row12 col0" >0.917946</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow12_col1" class="data row12 col1" >classification</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow12_col2" class="data row12 col2" >Dune</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row13" class="row_heading level0 row13" >9060</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow13_col0" class="data row13 col0" >0.926297</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow13_col1" class="data row13 col1" >classification_strat_6</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow13_col2" class="data row13 col2" >Dune</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row14" class="row_heading level0 row14" >9493</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow14_col0" class="data row14 col0" >0.925408</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow14_col1" class="data row14 col1" >classification_strat_8</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow14_col2" class="data row14 col2" >Dune</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row15" class="row_heading level0 row15" >3445</th>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow15_col0" class="data row15 col0" >0.895134</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow15_col1" class="data row15 col1" >regression</td>
#         <td id="T_ae64a168_207e_11e8_93c2_64006a775debrow15_col2" class="data row15 col2" >Dune</td>
#     </tr>    <tr>
#         <th id="T_ae64a168_207e_11e8_93c2_64006a775deblevel0_row16" class="row_heading le

# %%
def highlight_max(s,maxValues):
    #print(s)
    print(maxValues)
    print(s.name)
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s.name in maxValues
    #return ['background-color: yellow' if v else '' for v in is_max]
    print(['background-color: yellow' if is_max else ''])
    return ['background-color: yellow' if is_max else '' for i in s]

# %%
idx2 = dfLast.groupby("file")["accuracy"].transform(max) == dfLast["accuracy"]

# %%
dfLast[idx2]["accuracy"]
# Out:
# 5749    0.902500
# 7536    0.991981
# 7563    0.941685
# 9060    0.926297
# 4416    0.957145
# Name: accuracy, dtype: float64

# %%
idx2[idx2 == True].index.values
# Out:
# array([5749, 7536, 7563, 9060, 4416])

# %%
def highlight_max(s,maxValues):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    print(['background-color: yellow' if v else '' for v in is_max])
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
df.groupby(['sr']).mean().drop(['t'],axis=1).reset_index(level=0, inplace=True)["FN","FP","TN","TP","sr"].to_csv("./data-mean/Apache-test.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-6f2a55ddedc9> in <module>()
# ----> 1 df.groupby(['sr']).mean().drop(['t'],axis=1).reset_index(level=0, inplace=True)["FN","FP","TN","TP","sr"].to_csv("./data-mean/Apache-test.csv")
#
# TypeError: 'NoneType' object is not subscriptable

# %%
df2 = df.groupby(['sr']).mean().drop(['t'],axis=1)#.reset_index(level=0, inplace=True)

# %%
df2.reset_index(level=0, inplace=True)

# %%
df2[["TN","FN","TP","FP","sr"]].to_csv("./data-mean/Apache-test.csv", index=False)

# %%
for index,i in resultsList[idx].sort_values(["file"]).iterrows():
    #print(i)
    df2 = pd.read_csv(i['results'])
    df2 = df2.groupby(['sr']).mean().drop(['t'],axis=1)
    df2.reset_index(level=0, inplace=True)
    df2[["TN","FN","TP","FP","sr"]].to_csv("./data-mean/" + i['file'] + "-" + i['type'] + "-mean.csv", index=False)
    #break

# %%
resultsList.loc[(resultsList["file"]=="Apache") & (resultsList["type"]=="classification")].sort_values("accuracy", ascending=False)[:10]
# Out:
#      class_weight criterion    file  max_depth  max_features  max_leaf_nodes  \
# 432           NaN   entropy  Apache       40.0           NaN              10
# 864           NaN   entropy  Apache       80.0           NaN              10
# 324           NaN   entropy  Apache       30.0           NaN              10
# 732           NaN   entropy  Apache       60.0           NaN              80
# 0             NaN   entropy  Apache        NaN           NaN              10
# 192           NaN   entropy  Apache       10.0           NaN              80
# 12            NaN   entropy  Apache        NaN           NaN              20
# 540           NaN   entropy  Apache       50.0           NaN              10
# 744           NaN   entropy  Apache       60.0           NaN              90
# 252           NaN   entropy  Apache       20.0           NaN              40
#
#      min_impurity_decrease  min_samples_leaf  min_samples_split  \
# 432           1.000000e-07                 1                  2
# 864           1.000000e-07                 1                  2
# 324           1.000000e-07                 1                  2
# 732           1.000000e-07                 1                  2
# 0             1.000000e-07                 1                  2
# 192           1.000000e-07                 1                  2
# 12            1.000000e-07                 1                  2
# 540           1.000000e-07                 1                  2
# 744           1.000000e-07                 1                  2
# 252           1.000000e-07                 1                  2
#
#      min_weight_fraction_leaf  presort  random_state  \
# 432                       0.0    False           NaN
# 864                       0.0    False           NaN
# 324                       0.0    False           NaN
# 732                       0.0    False           NaN
# 0                         0.0    False           NaN
# 192                       0.0    False           NaN
# 12                        0.0    False           NaN
# 540                       0.0    False           NaN
# 744                       0.0    False           NaN
# 252                       0.0    False           NaN
#
#                                     results splitter            type  accuracy
# 432  ./data2/Apache-0217-classification.csv     best  classification  0.885848
# 864  ./data2/Apache-0433-classification.csv     best  classification  0.885731
# 324  ./data2/Apache-0163-classification.csv     best  classification  0.885263
# 732  ./data2/Apache-0367-classification.csv     best  classification  0.885234
# 0    ./data2/Apache-0001-classification.csv     best  classification  0.884415
# 192  ./data2/Apache-0097-classification.csv     best  classification  0.884327
# 12   ./data2/Apache-0007-classification.csv     best  classification  0.884152
# 540  ./data2/Apache-0271-classification.csv     best  classification  0.883889
# 744  ./data2/Apache-0373-classification.csv     best  classification  0.883860
# 252  ./data2/Apache-0127-classification.csv     best  classification  0.883655

# %%
resultsList.loc[(resultsList["file"]=="Apache") & (resultsList["type"]=="regression")].sort_values("accuracy", ascending=False)[:10]
# Out:
#       class_weight criterion    file  max_depth  max_features  max_leaf_nodes  \
# 625            NaN       mse  Apache       50.0           NaN              80
# 747            NaN       mse  Apache       60.0           NaN              90
# 85             NaN       mse  Apache        NaN           NaN              80
# 745            NaN       mse  Apache       60.0           NaN              90
# 987            NaN       mse  Apache       90.0           NaN              20
# 315            NaN       mse  Apache       20.0           NaN              90
# 817            NaN       mse  Apache       70.0           NaN              60
# 519            NaN       mse  Apache       40.0           NaN              80
# 961            NaN       mse  Apache       80.0           NaN              90
# 1069           NaN       mse  Apache       90.0           NaN              90
#
#       min_impurity_decrease  min_samples_leaf  min_samples_split  \
# 625            1.000000e-07                 1                  2
# 747            1.000000e-07                 2                  2
# 85             1.000000e-07                 1                  2
# 745            1.000000e-07                 1                  2
# 987            1.000000e-07                 2                  2
# 315            1.000000e-07                 2                  2
# 817            1.000000e-07                 1                  2
# 519            1.000000e-07                 2                  2
# 961            1.000000e-07                 1                  2
# 1069           1.000000e-07                 1                  2
#
#       min_weight_fraction_leaf  presort  random_state  \
# 625                        0.0    False           NaN
# 747                        0.0    False           NaN
# 85                         0.0    False           NaN
# 745                        0.0    False           NaN
# 987                        0.0    False           NaN
# 315                        0.0    False           NaN
# 817                        0.0    False           NaN
# 519                        0.0    False           NaN
# 961                        0.0    False           NaN
# 1069                       0.0    False           NaN
#
#                                  results splitter        type  accuracy
# 625   ./data2/Apache-0313-regression.csv     best  regression  0.896374
# 747   ./data2/Apache-0374-regression.csv     best  regression  0.895556
# 85    ./data2/Apache-0043-regression.csv     best  regression  0.894444
# 745   ./data2/Apache-0373-regression.csv     best  regression  0.894357
# 987   ./data2/Apache-0494-regression.csv     best  regression  0.894298
# 315   ./data2/Apache-0158-regression.csv     best  regression  0.894240
# 817   ./data2/Apache-0409-regression.csv     best  regression  0.894240
# 519   ./data2/Apache-0260-regression.csv     best  regression  0.894181
# 961   ./data2/Apache-0481-regression.csv     best  regression  0.894123
# 1069  ./data2/Apache-0535-regression.csv     best  regression  0.894094

# %%
resultsList.loc[(resultsList["file"]=="Apache") & (resultsList["type"]=="classification_strat")].sort_values("accuracy", ascending=False)[:10]
# Out:
#       class_weight criterion    file  max_depth  max_features  max_leaf_nodes  \
# 5568           NaN   entropy  Apache       30.0           NaN              20
# 5676           NaN   entropy  Apache       50.0           NaN              20
# 5784           NaN   entropy  Apache       70.0           NaN              20
# 5514           NaN   entropy  Apache       20.0           NaN              20
# 5838           NaN   entropy  Apache       80.0           NaN              20
# 5832           NaN   entropy  Apache       80.0           NaN              10
# 5934           NaN   entropy  Apache       90.0           NaN              90
# 5592           NaN   entropy  Apache       30.0           NaN              60
# 5622           NaN   entropy  Apache       40.0           NaN              20
# 5778           NaN   entropy  Apache       70.0           NaN              10
#
#       min_impurity_decrease  min_samples_leaf  min_samples_split  \
# 5568           1.000000e-07                 1                  2
# 5676           1.000000e-07                 1                  2
# 5784           1.000000e-07                 1                  2
# 5514           1.000000e-07                 1                  2
# 5838           1.000000e-07                 1                  2
# 5832           1.000000e-07                 1                  2
# 5934           1.000000e-07                 1                  2
# 5592           1.000000e-07                 1                  2
# 5622           1.000000e-07                 1                  2
# 5778           1.000000e-07                 1                  2
#
#       min_weight_fraction_leaf  presort  random_state  \
# 5568                       0.0    False           NaN
# 5676                       0.0    False           NaN
# 5784                       0.0    False           NaN
# 5514                       0.0    False           NaN
# 5838                       0.0    False           NaN
# 5832                       0.0    False           NaN
# 5934                       0.0    False           NaN
# 5592                       0.0    False           NaN
# 5622                       0.0    False           NaN
# 5778                       0.0    False           NaN
#
#                                            results splitter  \
# 5568  ./data2/Apache-0709-classification_strat.csv     best
# 5676  ./data2/Apache-0817-classification_strat.csv     best
# 5784  ./data2/Apache-0925-classification_strat.csv     best
# 5514  ./data2/Apache-0655-classification_strat.csv     best
# 5838  ./data2/Apache-0979-classification_strat.csv     best
# 5832  ./data2/Apache-0973-classification_strat.csv     best
# 5934  ./data2/Apache-1075-classification_strat.csv     best
# 5592  ./data2/Apache-0733-classification_strat.csv     best
# 5622  ./data2/Apache-0763-classification_strat.csv     best
# 5778  ./data2/Apache-0919-classification_strat.csv     best
#
#                       type  accuracy
# 5568  classification_strat  0.901420
# 5676  classification_strat  0.901019
# 5784  classification_strat  0.900833
# 5514  classification_strat  0.900247
# 5838  classification_strat  0.899969
# 5832  classification_strat  0.899969
# 5934  classification_strat  0.899938
# 5592  classification_strat  0.899784
# 5622  classification_strat  0.899660
# 5778  classification_strat  0.899475

# %%
configSet = []

for index, r in resultsList.loc[(resultsList["file"]=="Apache") & (resultsList["type"]=="classification_strat")].sort_values("accuracy", ascending=False)[:10].iterrows():
    configuration = {}
    for i in r.keys():
        if not i in ["results","type","accuracy","file"]:
            configuration[i] = r[i]
    configSet.append({"file":r["file"],"type":r["type"],"configuration":configuration})

# %%
resultset = [value for key, value in r.items() if key not in ["results","type","accuracy","file"]]

# %%
resultset
# Out:
# [nan, 'entropy', 30.0, nan, 20, 1e-07, 1, 2, 0.0, False, nan, 'best']

# %%
configuration = {}
for i in r.keys():
    if not i in ["results","type","accuracy","file"]:
        configuration[i] = r[i]

# %%
configuration
# Out:
# {'class_weight': nan,
#  'criterion': 'entropy',
#  'max_depth': 30.0,
#  'max_features': nan,
#  'max_leaf_nodes': 20,
#  'min_impurity_decrease': 1e-07,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': False,
#  'random_state': nan,
#  'splitter': 'lol'}

# %%
configSet
# Out:
# [{'configuration': {'class_weight': nan,
#    'criterion': 'entropy',
#    'max_depth': 30.0,
#    'max_features': nan,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1e-07,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'min_weight_fraction_leaf': 0.0,
#    'presort': False,
#    'random_state': nan,
#    'splitter': 'best'},
#   'file': 'Apache',
#   'type': 'classification_strat'},
#  {'configuration': {'class_weight': nan,
#    'criterion': 'entropy',
#    'max_depth': 50.0,
#    'max_features': nan,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1e-07,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'min_weight_fraction_leaf': 0.0,
#    'presort': False,
#    'random_state': nan,
#    'splitter': 'best'},
#   'file': 'Apache',
#   'type': 'classification_strat'},
#  {'configuration': {'class_weight': nan,
#    'criterion': 'entropy',
#    'max_depth': 70.0,
#    'max_features': nan,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1e-07,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'min_weight_fraction_leaf': 0.0,
#    'presort': False,
#    'random_state': nan,
#    'splitter': 'best'},
#   'file': 'Apache',
#   'type': 'classification_strat'},
#  {'configuration': {'class_weight': nan,
#    'criterion': 'entropy',
#    'max_depth': 20.0,
#    'max_features': nan,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1e-07,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'min_weight_fraction_leaf': 0.0,
#    'presort': False,
#    'random_state': nan,
#    'splitter': 'best'},
#   'file': 'Apache',
#   'type': 'classification_strat'},
#  {'configuration': {'class_weight': nan,
#    'criterion': 'entropy',
#    'max_depth': 80.0,
#    'max_features': nan,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1e-07,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'min_weight_fraction_leaf': 0.0,
#    'presort': False,
#    'random_state': nan,
#    'splitter': 'best'},
#   'file': 'Apache',
#   'type': 'classification_strat'},
#  {'configuration': {'class_weight': nan,
#    'criterion': 'entropy',
#    'max_depth': 80.0,
#    'max_features': nan,
#    'max_leaf_nodes': 10,
#    'min_impurity_decrease': 1e-07,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'min_weight_fraction_leaf': 0.0,
#    'presort': False,
#    'random_state': nan,
#    'splitter': 'best'},
#   'file': 'Apache',
#   'type': 'classification_strat'},
#  {'configuration': {'class_weight': nan,
#    'criterion': 'entropy',
#    'max_depth': 90.0,
#    'max_features': nan,
#    'max_leaf_nodes': 90,
#    'min_impurity_decrease': 1e-07,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'min_weight_fraction_leaf': 0.0,
#    'presort': False,
#    'random_state': nan,
#    'splitter': 'best'},
#   'file': 'Apache',
#   'type': 'classification_strat'},
#  {'configuration': {'class_weight': nan,
#    'criterion': 'entropy',
#    'max_depth': 30.0,
#    'max_features': nan,
#    'max_leaf_nodes': 60,
#    'min_impurity_decrease': 1e-07,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'min_weight_fraction_leaf': 0.0,
#    'presort': False,
#    'random_state': nan,
#    'splitter': 'best'},
#   'file': 'Apache',
#   'type': 'classification_strat'},
#  {'configuration': {'class_weight': nan,
#    'criterion': 'entropy',
#    'max_depth': 40.0,
#    'max_features': nan,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 1e-07,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'min_weight_fraction_leaf': 0.0,
#    'presort': False,
#    'random_state': nan,
#    'splitter': 'best'},
#   'file': 'Apache',
#   'type': 'classification_strat'},
#  {'configuration': {'class_weight': nan,
#    'criterion': 'entropy',
#    'max_depth': 70.0,
#    'max_features': nan,
#    'max_leaf_nodes': 10,
#    'min_impurity_decrease': 1e-07,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'min_weight_fraction_leaf': 0.0,
#    'presort': False,
#    'random_state': nan,
#    'splitter': 'best'},
#   'file': 'Apache',
#   'type': 'classification_strat'}]

# %%
for f in resultsList.file.unique():
    print(f)
# Out:
# Apache
# BerkeleyC
# BerkeleyJ
# Dune
# HIPAcc

# %%
for t in resultsList.type.unique():
    print(t)
# Out:
# classification
# regression
# classification_strat

# %%
configSet = []
for f in resultsList.file.unique():
    for t in resultsList.type.unique():
        for index, r in resultsList.loc[(resultsList["file"]==f) & (resultsList["type"]==t)].sort_values("accuracy", ascending=False)[:10].iterrows():
            configuration = {}
            for i in r.keys():
                if not i in ["results","type","accuracy","file"]:
                    configuration[i] = r[i]
            configSet.append({"file":r["file"],"type":r["type"],"configuration":configuration})

# %%
dfConfig = pd.DataFrame(configSet)
dfConfig
# Out:
#                                          configuration    file  \
# 0    {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 1    {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 2    {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 3    {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 4    {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 5    {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 6    {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 7    {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 8    {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 9    {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 10   {'class_weight': nan, 'criterion': 'mse', 'max...  Apache
# 11   {'class_weight': nan, 'criterion': 'mse', 'max...  Apache
# 12   {'class_weight': nan, 'criterion': 'mse', 'max...  Apache
# 13   {'class_weight': nan, 'criterion': 'mse', 'max...  Apache
# 14   {'class_weight': nan, 'criterion': 'mse', 'max...  Apache
# 15   {'class_weight': nan, 'criterion': 'mse', 'max...  Apache
# 16   {'class_weight': nan, 'criterion': 'mse', 'max...  Apache
# 17   {'class_weight': nan, 'criterion': 'mse', 'max...  Apache
# 18   {'class_weight': nan, 'criterion': 'mse', 'max...  Apache
# 19   {'class_weight': nan, 'criterion': 'mse', 'max...  Apache
# 20   {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 21   {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 22   {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 23   {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 24   {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 25   {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 26   {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 27   {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 28   {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# 29   {'class_weight': nan, 'criterion': 'entropy', ...  Apache
# ..                                                 ...     ...
# 170  {'class_weight': nan, 'criterion': 'mse', 'max...  HIPAcc
# 171  {'class_weight': nan, 'criterion': 'mse', 'max...  HIPAcc
# 172  {'class_weight': nan, 'criterion': 'mse', 'max...  HIPAcc
# 173  {'class_weight': nan, 'criterion': 'mse', 'max...  HIPAcc
# 174  {'class_weight': nan, 'criterion': 'mse', 'max...  HIPAcc
# 175  {'class_weight': nan, 'criterion': 'mse', 'max...  HIPAcc
# 176  {'class_weight': nan, 'criterion': 'mse', 'max...  HIPAcc
# 177  {'class_weight': nan, 'criterion': 'mse', 'max...  HIPAcc
# 178  {'class_weight': nan, 'criterion': 'mse', 'max...  HIPAcc
# 179  {'class_weight': nan, 'criterion': 'mse', 'max...  HIPAcc
# 180  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 181  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 182  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 183  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 184  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 185  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 186  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 187  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 188  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 189  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 190  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 191  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 192  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 193  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 194  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 195  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 196  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 197  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 198  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
# 199  {'class_weight': nan, 'criterion': 'entropy', ...  HIPAcc
#
#                        type
# 0            classification
# 1            classification
# 2            classification
# 3            classification
# 4            classification
# 5            classification
# 6            classification
# 7            classification
# 8            classification
# 9            classification
# 10               regression
# 11               regression
# 12               regression
# 13               regression
# 14               regression
# 15               regression
# 16               regression
# 17               regression
# 18               regression
# 19               regression
# 20   classification_strat_6
# 21   classification_strat_6
# 22   classification_strat_6
# 23   classification_strat_6
# 24   classification_strat_6
# 25   classification_strat_6
# 26   classification_strat_6
# 27   classification_strat_6
# 28   classification_strat_6
# 29   classification_strat_6
# ..                      ...
# 170              regression
# 171              regression
# 172              regression
# 173              regression
# 174              regression
# 175              regression
# 176              regression
# 177              regression
# 178              regression
# 179              regression
# 180  classification_strat_6
# 181  classification_strat_6
# 182  classification_strat_6
# 183  classification_strat_6
# 184  classification_strat_6
# 185  classification_strat_6
# 186  classification_strat_6
# 187  classification_strat_6
# 188  classification_strat_6
# 189  classification_strat_6
# 190  classification_strat_8
# 191  classification_strat_8
# 192  classification_strat_8
# 193  classification_strat_8
# 194  classification_strat_8
# 195  classification_strat_8
# 196  classification_strat_8
# 197  classification_strat_8
# 198  classification_strat_8
# 199  classification_strat_8
#
# [200 rows x 3 columns]

# %%
resultsList = pd.read_csv("./data3/results-list.csv")

# %%
serie = []
for i in resultsList['results']:
    serie.append(i.split("-")[2].split(".")[0])
#print(serie)

serie = pd.Series(serie)

resultsList['type'] = serie

# %%
resultsList
# Out:
#      class_weight criterion    file  max_depth  max_features  max_leaf_nodes  \
# 0             NaN   entropy  Apache       40.0           NaN              10
# 1             NaN   entropy  Apache       80.0           NaN              10
# 2             NaN   entropy  Apache       30.0           NaN              10
# 3             NaN   entropy  Apache       60.0           NaN              80
# 4             NaN   entropy  Apache        NaN           NaN              10
# 5             NaN   entropy  Apache       10.0           NaN              80
# 6             NaN   entropy  Apache        NaN           NaN              20
# 7             NaN   entropy  Apache       50.0           NaN              10
# 8             NaN   entropy  Apache       60.0           NaN              90
# 9             NaN   entropy  Apache       20.0           NaN              40
# 10            NaN       mse  Apache       50.0           NaN              80
# 11            NaN       mse  Apache       60.0           NaN              90
# 12            NaN       mse  Apache        NaN           NaN              80
# 13            NaN       mse  Apache       60.0           NaN              90
# 14            NaN       mse  Apache       90.0           NaN              20
# 15            NaN       mse  Apache       20.0           NaN              90
# 16            NaN       mse  Apache       70.0           NaN              60
# 17            NaN       mse  Apache       40.0           NaN              80
# 18            NaN       mse  Apache       80.0           NaN              90
# 19            NaN       mse  Apache       90.0           NaN              90
# 20            NaN   entropy  Apache       30.0           NaN              20
# 21            NaN   entropy  Apache       10.0           NaN              20
# 22            NaN   entropy  Apache       20.0           NaN              20
# 23            NaN   entropy  Apache       90.0           NaN              20
# 24            NaN   entropy  Apache       20.0           NaN              30
# 25            NaN   entropy  Apache       60.0           NaN              20
# 26            NaN   entropy  Apache       40.0           NaN              20
# 27            NaN   entropy  Apache        NaN           NaN              50
# 28            NaN   entropy  Apache       10.0           NaN              30
# 29            NaN   entropy  Apache       70.0           NaN              20
# ..            ...       ...     ...        ...           ...             ...
# 170           NaN       mse  HIPAcc       40.0           NaN              90
# 171           NaN       mse  HIPAcc       50.0           NaN              90
# 172           NaN       mse  HIPAcc       20.0           NaN              90
# 173           NaN       mse  HIPAcc       50.0           NaN              90
# 174           NaN       mse  HIPAcc       30.0           NaN              90
# 175           NaN       mse  HIPAcc       40.0           NaN              90
# 176           NaN       mse  HIPAcc        NaN           NaN              90
# 177           NaN       mse  HIPAcc       90.0           NaN              90
# 178           NaN       mse  HIPAcc       30.0           NaN              90
# 179           NaN       mse  HIPAcc       90.0           NaN              90
# 180           NaN   entropy  HIPAcc       30.0           NaN              90
# 181           NaN   entropy  HIPAcc        NaN           NaN              90
# 182           NaN   entropy  HIPAcc        NaN           NaN              90
# 183           NaN   entropy  HIPAcc       60.0           NaN              90
# 184           NaN   entropy  HIPAcc       70.0           NaN              90
# 185           NaN   entropy  HIPAcc       90.0           NaN              90
# 186           NaN   entropy  HIPAcc       50.0           NaN              90
# 187           NaN   entropy  HIPAcc       80.0           NaN              90
# 188           NaN   entropy  HIPAcc       20.0           NaN              90
# 189           NaN   entropy  HIPAcc       40.0           NaN              90
# 190           NaN   entropy  HIPAcc       40.0           NaN              90
# 191           NaN   entropy  HIPAcc       70.0           NaN              90
# 192           NaN   entropy  HIPAcc        NaN           NaN              90
# 193           NaN   entropy  HIPAcc       60.0           NaN              90
# 194           NaN   entropy  HIPAcc       90.0           NaN              90
# 195           NaN   entropy  HIPAcc       30.0           NaN              90
# 196           NaN   entropy  HIPAcc       50.0           NaN              90
# 197           NaN   entropy  HIPAcc       80.0           NaN              90
# 198           NaN   entropy  HIPAcc       20.0           NaN              90
# 199           NaN   entropy  HIPAcc       40.0           NaN              90
#
#      min_impurity_decrease  min_samples_leaf  min_samples_split  \
# 0             1.000000e-07                 1                  2
# 1             1.000000e-07                 1                  2
# 2             1.000000e-07                 1                  2
# 3             1.000000e-07                 1                  2
# 4             1.000000e-07                 1                  2
# 5             1.000000e-07                 1                  2
# 6             1.000000e-07                 1                  2
# 7             1.000000e-07                 1                  2
# 8             1.000000e-07                 1                  2
# 9             1.000000e-07                 1                  2
# 10            1.000000e-07                 1                  2
# 11            1.000000e-07                 2                  2
# 12            1.000000e-07                 1                  2
# 13            1.000000e-07                 1                  2
# 14            1.000000e-07                 2                  2
# 15            1.000000e-07                 2                  2
# 16            1.000000e-07                 1                  2
# 17            1.000000e-07                 2                  2
# 18            1.000000e-07                 1                  2
# 19            1.000000e-07                 1                  2
# 20            1.000000e-07                 1                  2
# 21            1.000000e-07                 1                  2
# 22            1.000000e-07                 1                  2
# 23            1.000000e-07                 1                  2
# 24            1.000000e-07                 1                  2
# 25            1.000000e-07                 1                  2
# 26            1.000000e-07                 1                  2
# 27            1.000000e-07                 1                  2
# 28            1.000000e-07                 1                  2
# 29            1.000000e-07                 1                  2
# ..                     ...               ...                ...
# 170           1.000000e-07                 1                  2
# 171           1.000000e-07                 2                  2
# 172           1.000000e-07                 4                  2
# 173           1.000000e-07                 1                  2
# 174           1.000000e-07                 2                  2
# 175           1.000000e-07                 2                  2
# 176           1.000000e-07                 2                  2
# 177           1.000000e-07                 2                  2
# 178           1.000000e-07                 4                  2
# 179           1.000000e-07                 1                  2
# 180           1.000000e-07                 1                  2
# 181           1.000000e-07                 2                  2
# 182           1.000000e-07                 1                  2
# 183           1.000000e-07                 2                  2
# 184           1.000000e-07                 2                  2
# 185           1.000000e-07                 1                  2
# 186           1.000000e-07                 2                  2
# 187           1.000000e-07                 1                  2
# 188           1.000000e-07                 1                  2
# 189           1.000000e-07                 1                  2
# 190           1.000000e-07                 1                  2
# 191           1.000000e-07                 1                  2
# 192           1.000000e-07                 1                  2
# 193           1.000000e-07                 1                  2
# 194           1.000000e-07                 1                  2
# 195           1.000000e-07                 1                  2
# 196           1.000000e-07                 1                  2
# 197           1.000000e-07                 1                  2
# 198           1.000000e-07                 1                  2
# 199           1.000000e-07                 2                  2
#
#      min_weight_fraction_leaf  presort  random_state  \
# 0                         0.0    False           NaN
# 1                         0.0    False           NaN
# 2                         0.0    False           NaN
# 3                         0.0    False           NaN
# 4                         0.0    False           NaN
# 5                         0.0    False           NaN
# 6                         0.0    False           NaN
# 7                         0.0    False           NaN
# 8                         0.0    False           NaN
# 9                         0.0    False           NaN
# 10                        0.0    False           NaN
# 11                        0.0    False           NaN
# 12                        0.0    False           NaN
# 13                        0.0    False           NaN
# 14                        0.0    False           NaN
# 15                        0.0    False           NaN
# 16                        0.0    False           NaN
# 17                        0.0    False           NaN
# 18                        0.0    False           NaN
# 19                        0.0    False           NaN
# 20                        0.0    False           NaN
# 21                        0.0    False           NaN
# 22                        0.0    False           NaN
# 23                        0.0    False           NaN
# 24                        0.0    False           NaN
# 25                        0.0    False           NaN
# 26                        0.0    False           NaN
# 27                        0.0    False           NaN
# 28                        0.0    False           NaN
# 29                        0.0    False           NaN
# ..                        ...      ...           ...
# 170                       0.0    False           NaN
# 171                       0.0    False           NaN
# 172                       0.0    False           NaN
# 173                       0.0    False           NaN
# 174                       0.0    False           NaN
# 175                       0.0    False           NaN
# 176                       0.0    False           NaN
# 177                       0.0    False           NaN
# 178                       0.0    False           NaN
# 179                       0.0    False           NaN
# 180                       0.0    False           NaN
# 181                       0.0    False           NaN
# 182                       0.0    False           NaN
# 183                       0.0    False           NaN
# 184                       0.0    False           NaN
# 185                       0.0    False           NaN
# 186                       0.0    False           NaN
# 187                       0.0    False           NaN
# 188                       0.0    False           NaN
# 189                       0.0    False           NaN
# 190                       0.0    False           NaN
# 191                       0.0    False           NaN
# 192                       0.0    False           NaN
# 193                       0.0    False           NaN
# 194                       0.0    False           NaN
# 195                       0.0    False           NaN
# 196                       0.0    False           NaN
# 197                       0.0    False           NaN
# 198                       0.0    False           NaN
# 199                       0.0    False           NaN
#
#                                             results splitter  \
# 0            ./data3/Apache-0001-classification.csv     best
# 1            ./data3/Apache-0002-classification.csv     best
# 2            ./data3/Apache-0003-classification.csv     best
# 3            ./data3/Apache-0004-classification.csv     best
# 4            ./data3/Apache-0005-classification.csv     best
# 5            ./data3/Apache-0006-classification.csv     best
# 6            ./data3/Apache-0007-classification.csv     best
# 7            ./data3/Apache-0008-classification.csv     best
# 8            ./data3/Apache-0009-classification.csv     best
# 9            ./data3/Apache-0010-classification.csv     best
# 10               ./data3/Apache-0011-regression.csv     best
# 11               ./data3/Apache-0012-regression.csv     best
# 12               ./data3/Apache-0013-regression.csv     best
# 13               ./data3/Apache-0014-regression.csv     best
# 14               ./data3/Apache-0015-regression.csv     best
# 15               ./data3/Apache-0016-regression.csv     best
# 16               ./data3/Apache-0017-regression.csv     best
# 17               ./data3/Apache-0018-regression.csv     best
# 18               ./data3/Apache-0019-regression.csv     best
# 19               ./data3/Apache-0020-regression.csv     best
# 20   ./data3/Apache-0021-classification_strat_6.csv     best
# 21   ./data3/Apache-0022-classification_strat_6.csv     best
# 22   ./data3/Apache-0023-classification_strat_6.csv     best
# 23   ./data3/Apache-0024-classification_strat_6.csv     best
# 24   ./data3/Apache-0025-classification_strat_6.csv     best
# 25   ./data3/Apache-0026-classification_strat_6.csv     best
# 26   ./data3/Apache-0027-classification_strat_6.csv     best
# 27   ./data3/Apache-0028-classification_strat_6.csv     best
# 28   ./data3/Apache-0029-classification_strat_6.csv     best
# 29   ./data3/Apache-0030-classification_strat_6.csv     best
# ..                                              ...      ...
# 170              ./data3/HIPAcc-0011-regression.csv     best
# 171              ./data3/HIPAcc-0012-regression.csv     best
# 172              ./data3/HIPAcc-0013-regression.csv     best
# 173              ./data3/HIPAcc-0014-regression.csv     best
# 174              ./data3/HIPAcc-0015-regression.csv     best
# 175              ./data3/HIPAcc-0016-regression.csv     best
# 176              ./data3/HIPAcc-0017-regression.csv     best
# 177              ./data3/HIPAcc-0018-regression.csv     best
# 178              ./data3/HIPAcc-0019-regression.csv     best
# 179              ./data3/HIPAcc-0020-regression.csv     best
# 180  ./data3/HIPAcc-0021-classification_strat_6.csv     best
# 181  ./data3/HIPAcc-0022-classification_strat_6.csv     best
# 182  ./data3/HIPAcc-0023-classification_strat_6.csv     best
# 183  ./data3/HIPAcc-0024-classification_strat_6.csv     best
# 184  ./data3/HIPAcc-0025-classification_strat_6.csv     best
# 185  ./data3/HIPAcc-0026-classification_strat_6.csv     best
# 186  ./data3/HIPAcc-0027-classification_strat_6.csv     best
# 187  ./data3/HIPAcc-0028-classification_strat_6.csv     best
# 188  ./data3/HIPAcc-0029-classification_strat_6.csv     best
# 189  ./data3/HIPAcc-0030-classification_strat_6.csv     best
# 190  ./data3/HIPAcc-0031-classification_strat_8.csv     best
# 191  ./data3/HIPAcc-0032-classification_strat_8.csv     best
# 192  ./data3/HIPAcc-0033-classification_strat_8.csv     best
# 193  ./data3/HIPAcc-0034-classification_strat_8.csv     best
# 194  ./data3/HIPAcc-0035-classification_strat_8.csv     best
# 195  ./data3/HIPAcc-0036-classification_strat_8.csv     best
# 196  ./data3/HIPAcc-0037-classification_strat_8.csv     best
# 197  ./data3/HIPAcc-0038-classification_strat_8.csv     best
# 198  ./data3/HIPAcc-0039-classification_strat_8.csv     best
# 199  ./data3/HIPAcc-0040-classification_strat_8.csv     best
#
#                        type
# 0            classification
# 1            classification
# 2            classification
# 3            classification
# 4            classification
# 5            classification
# 6            classification
# 7            classification
# 8            classification
# 9            classification
# 10               regression
# 11               regression
# 12               regression
# 13               regression
# 14               regression
# 15               regression
# 16               regression
# 17               regression
# 18               regression
# 19               regression
# 20   classification_strat_6
# 21   classification_strat_6
# 22   classification_strat_6
# 23   classification_strat_6
# 24   classification_strat_6
# 25   classification_strat_6
# 26   classification_strat_6
# 27   classification_strat_6
# 28   classification_strat_6
# 29   classification_strat_6
# ..                      ...
# 170              regression
# 171              regression
# 172              regression
# 173              regression
# 174              regression
# 175              regression
# 176              regression
# 177              regression
# 178              regression
# 179              regression
# 180  classification_strat_6
# 181  classification_strat_6
# 182  classification_strat_6
# 183  classification_strat_6
# 184  classification_strat_6
# 185  classification_strat_6
# 186  classification_strat_6
# 187  classification_strat_6
# 188  classification_strat_6
# 189  classification_strat_6
# 190  classification_strat_8
# 191  classification_strat_8
# 192  classification_strat_8
# 193  classification_strat_8
# 194  classification_strat_8
# 195  classification_strat_8
# 196  classification_strat_8
# 197  classification_strat_8
# 198  classification_strat_8
# 199  classification_strat_8
#
# [200 rows x 15 columns]

# %%
accuracy = []
for i in resultsList['results']:
    dfTemp = pd.read_csv(i)
    dfMean = dfTemp.groupby(['sr']).mean().drop(['t'],axis=1)
    dfMean['accuracy']= (dfMean['TP']+dfMean['TN']) / (dfMean['TP']+dfMean['TN']+dfMean['FN']+dfMean['FP'])
    accuracy.append(dfMean['accuracy'].mean())
resultsList['accuracy'] = pd.Series(accuracy)

idx = resultsList.groupby(["file","type"])["accuracy"].transform(max) == resultsList['accuracy']
resultsList[idx][resultsList['type'] == "classification"].sort_values(["file","accuracy"])
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # Remove the CWD from sys.path while we load stuff.
#      class_weight criterion       file  max_depth  max_features  \
# 0             NaN   entropy     Apache       40.0           NaN
# 45            NaN   entropy  BerkeleyC       90.0           NaN
# 87            NaN   entropy  BerkeleyJ       50.0           NaN
# 125           NaN   entropy       Dune       40.0           NaN
# 168           NaN   entropy     HIPAcc       60.0           NaN
#
#      max_leaf_nodes  min_impurity_decrease  min_samples_leaf  \
# 0                10           1.000000e-07                 1
# 45               90           1.000000e-07                 1
# 87               90           1.000000e-07                 1
# 125              90           1.000000e-07                 1
# 168              90           1.000000e-07                 1
#
#      min_samples_split  min_weight_fraction_leaf  presort  random_state  \
# 0                    2                       0.0    False           NaN
# 45                   2                       0.0    False           NaN
# 87                   2                       0.0    False           NaN
# 125                  2                       0.0    False           NaN
# 168                  2                       0.0    False           NaN
#
#                                        results splitter            type  \
# 0       ./data3/Apache-0001-classification.csv     best  classification
# 45   ./data3/BerkeleyC-0006-classification.csv     best  classification
# 87   ./data3/BerkeleyJ-0008-classification.csv     best  classification
# 125       ./data3/Dune-0006-classification.csv     best  classification
# 168     ./data3/HIPAcc-0009-classification.csv     best  classification
#
#      accuracy
# 0    0.898975
# 45   0.986648
# 87   0.925418
# 125  0.927133
# 168  0.968103

# %%
resultsList[idx][(resultsList['type'] == "classification") | (resultsList['type'] == "regression")].sort_values(["file","accuracy"], ascending=[True,False])
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#      class_weight criterion       file  max_depth  max_features  \
# 17            NaN       mse     Apache       40.0           NaN
# 0             NaN   entropy     Apache       40.0           NaN
# 51            NaN       mse  BerkeleyC       30.0           NaN
# 45            NaN   entropy  BerkeleyC       90.0           NaN
# 91            NaN       mse  BerkeleyJ       40.0           NaN
# 87            NaN   entropy  BerkeleyJ       50.0           NaN
# 125           NaN   entropy       Dune       40.0           NaN
# 131           NaN       mse       Dune       60.0           NaN
# 168           NaN   entropy     HIPAcc       60.0           NaN
# 171           NaN       mse     HIPAcc       50.0           NaN
#
#      max_leaf_nodes  min_impurity_decrease  min_samples_leaf  \
# 17               80           1.000000e-07                 2
# 0                10           1.000000e-07                 1
# 51               90           1.000000e-07                 1
# 45               90           1.000000e-07                 1
# 91               20           1.000000e-07                 1
# 87               90           1.000000e-07                 1
# 125              90           1.000000e-07                 1
# 131              90           1.000000e-07                 2
# 168              90           1.000000e-07                 1
# 171              90           1.000000e-07                 2
#
#      min_samples_split  min_weight_fraction_leaf  presort  random_state  \
# 17                   2                       0.0    False           NaN
# 0                    2                       0.0    False           NaN
# 51                   2                       0.0    False           NaN
# 45                   2                       0.0    False           NaN
# 91                   2                       0.0    False           NaN
# 87                   2                       0.0    False           NaN
# 125                  2                       0.0    False           NaN
# 131                  2                       0.0    False           NaN
# 168                  2                       0.0    False           NaN
# 171                  2                       0.0    False           NaN
#
#                                        results splitter            type  \
# 17          ./data3/Apache-0018-regression.csv     best      regression
# 0       ./data3/Apache-0001-classification.csv     best  classification
# 51       ./data3/BerkeleyC-0012-regression.csv     best      regression
# 45   ./data3/BerkeleyC-0006-classification.csv     best  classification
# 91       ./data3/BerkeleyJ-0012-regression.csv     best      regression
# 87   ./data3/BerkeleyJ-0008-classification.csv     best  classification
# 125       ./data3/Dune-0006-classification.csv     best  classification
# 131           ./data3/Dune-0012-regression.csv     best      regression
# 168     ./data3/HIPAcc-0009-classification.csv     best  classification
# 171         ./data3/HIPAcc-0012-regression.csv     best      regression
#
#      accuracy
# 17   0.907197
# 0    0.898975
# 51   0.989211
# 45   0.986648
# 91   0.935394
# 87   0.925418
# 125  0.927133
# 131  0.910099
# 168  0.968103
# 171  0.922290

# %%
configSet = []
resultsList2 = resultsList[idx][(resultsList['type'] == "classification") | (resultsList['type'] == "regression")].where(pd.notnull(resultsList), None)
for f in resultsList2.file.unique():
    for t in resultsList2.type.unique():
        for index, r in resultsList2.loc[(resultsList["file"]==f) & (resultsList2["type"]==t)].sort_values("accuracy", ascending=False)[:10].iterrows():
            configuration = {}
            for i in r.keys():
                if not i in ["results","type","accuracy","file"]:
                    if not (r["type"] == "regression" and i=="class_weight"):
                        configuration[i] = r[i]
            configSet.append({"file":r["file"],"type":r["type"],"configuration":configuration})
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
pd.DataFrame(configSet)
# Out:
#                                        configuration       file  \
# 0  {'class_weight': None, 'criterion': 'entropy',...     Apache
# 1  {'criterion': 'mse', 'max_depth': 40.0, 'max_f...     Apache
# 2  {'class_weight': None, 'criterion': 'entropy',...  BerkeleyC
# 3  {'criterion': 'mse', 'max_depth': 30.0, 'max_f...  BerkeleyC
# 4  {'class_weight': None, 'criterion': 'entropy',...  BerkeleyJ
# 5  {'criterion': 'mse', 'max_depth': 40.0, 'max_f...  BerkeleyJ
# 6  {'class_weight': None, 'criterion': 'entropy',...       Dune
# 7  {'criterion': 'mse', 'max_depth': 60.0, 'max_f...       Dune
# 8  {'class_weight': None, 'criterion': 'entropy',...     HIPAcc
# 9  {'criterion': 'mse', 'max_depth': 50.0, 'max_f...     HIPAcc
#
#              type
# 0  classification
# 1      regression
# 2  classification
# 3      regression
# 4  classification
# 5      regression
# 6  classification
# 7      regression
# 8  classification
# 9      regression

# %%
resultsList = pd.read_csv("./data2/results-list.csv")
resultsList
# Out:
#        class_weight criterion    file  max_depth  max_features  \
# 0               NaN   entropy  Apache        NaN           NaN
# 1               NaN       mse  Apache        NaN           NaN
# 2               NaN   entropy  Apache        NaN           NaN
# 3               NaN       mse  Apache        NaN           NaN
# 4               NaN   entropy  Apache        NaN           NaN
# 5               NaN       mse  Apache        NaN           NaN
# 6               NaN   entropy  Apache        NaN           NaN
# 7               NaN       mse  Apache        NaN           NaN
# 8               NaN   entropy  Apache        NaN           NaN
# 9               NaN       mse  Apache        NaN           NaN
# 10              NaN   entropy  Apache        NaN           NaN
# 11              NaN       mse  Apache        NaN           NaN
# 12              NaN   entropy  Apache        NaN           NaN
# 13              NaN       mse  Apache        NaN           NaN
# 14              NaN   entropy  Apache        NaN           NaN
# 15              NaN       mse  Apache        NaN           NaN
# 16              NaN   entropy  Apache        NaN           NaN
# 17              NaN       mse  Apache        NaN           NaN
# 18              NaN   entropy  Apache        NaN           NaN
# 19              NaN       mse  Apache        NaN           NaN
# 20              NaN   entropy  Apache        NaN           NaN
# 21              NaN       mse  Apache        NaN           NaN
# 22              NaN   entropy  Apache        NaN           NaN
# 23              NaN       mse  Apache        NaN           NaN
# 24              NaN   entropy  Apache        NaN           NaN
# 25              NaN       mse  Apache        NaN           NaN
# 26              NaN   entropy  Apache        NaN           NaN
# 27              NaN       mse  Apache        NaN           NaN
# 28              NaN   entropy  Apache        NaN           NaN
# 29              NaN       mse  Apache        NaN           NaN
# ...             ...       ...     ...        ...           ...
# 10770           NaN   entropy  HIPAcc       90.0           NaN
# 10771           NaN   entropy  HIPAcc       90.0           NaN
# 10772           NaN   entropy  HIPAcc       90.0           NaN
# 10773           NaN   entropy  HIPAcc       90.0           NaN
# 10774           NaN   entropy  HIPAcc       90.0           NaN
# 10775           NaN   entropy  HIPAcc       90.0           NaN
# 10776           NaN   entropy  HIPAcc       90.0           NaN
# 10777           NaN   entropy  HIPAcc       90.0           NaN
# 10778           NaN   entropy  HIPAcc       90.0           NaN
# 10779           NaN   entropy  HIPAcc       90.0           NaN
# 10780           NaN   entropy  HIPAcc       90.0           NaN
# 10781           NaN   entropy  HIPAcc       90.0           NaN
# 10782           NaN   entropy  HIPAcc       90.0           NaN
# 10783           NaN   entropy  HIPAcc       90.0           NaN
# 10784           NaN   entropy  HIPAcc       90.0           NaN
# 10785           NaN   entropy  HIPAcc       90.0           NaN
# 10786           NaN   entropy  HIPAcc       90.0           NaN
# 10787           NaN   entropy  HIPAcc       90.0           NaN
# 10788           NaN   entropy  HIPAcc       90.0           NaN
# 10789           NaN   entropy  HIPAcc       90.0           NaN
# 10790           NaN   entropy  HIPAcc       90.0           NaN
# 10791           NaN   entropy  HIPAcc       90.0           NaN
# 10792           NaN   entropy  HIPAcc       90.0           NaN
# 10793           NaN   entropy  HIPAcc       90.0           NaN
# 10794           NaN   entropy  HIPAcc       90.0           NaN
# 10795           NaN   entropy  HIPAcc       90.0           NaN
# 10796           NaN   entropy  HIPAcc       90.0           NaN
# 10797           NaN   entropy  HIPAcc       90.0           NaN
# 10798           NaN   entropy  HIPAcc       90.0           NaN
# 10799           NaN   entropy  HIPAcc       90.0           NaN
#
#        max_leaf_nodes  min_impurity_decrease  min_samples_leaf  \
# 0                  10           1.000000e-07                 1
# 1                  10           1.000000e-07                 1
# 2                  10           1.000000e-07                 2
# 3                  10           1.000000e-07                 2
# 4                  10           1.000000e-07                 4
# 5                  10           1.000000e-07                 4
# 6                  10           1.000000e-07                 6
# 7                  10           1.000000e-07                 6
# 8                  10           1.000000e-07                 8
# 9                  10           1.000000e-07                 8
# 10                 10           1.000000e-07                10
# 11                 10           1.000000e-07                10
# 12                 20           1.000000e-07                 1
# 13                 20           1.000000e-07                 1
# 14                 20           1.000000e-07                 2
# 15                 20           1.000000e-07                 2
# 16                 20           1.000000e-07                 4
# 17                 20           1.000000e-07                 4
# 18                 20           1.000000e-07                 6
# 19                 20           1.000000e-07                 6
# 20                 20           1.000000e-07                 8
# 21                 20           1.000000e-07                 8
# 22                 20           1.000000e-07                10
# 23                 20           1.000000e-07                10
# 24                 30           1.000000e-07                 1
# 25                 30           1.000000e-07                 1
# 26                 30           1.000000e-07                 2
# 27                 30           1.000000e-07                 2
# 28                 30           1.000000e-07                 4
# 29                 30           1.000000e-07                 4
# ...               ...                    ...               ...
# 10770              70           1.000000e-07                 6
# 10771              70           1.000000e-07                 6
# 10772              70           1.000000e-07                 8
# 10773              70           1.000000e-07                 8
# 10774              70           1.000000e-07                10
# 10775              70           1.000000e-07                10
# 10776              80           1.000000e-07                 1
# 10777              80           1.000000e-07                 1
# 10778              80           1.000000e-07                 2
# 10779              80           1.000000e-07                 2
# 10780              80           1.000000e-07                 4
# 10781              80           1.000000e-07                 4
# 10782              80           1.000000e-07                 6
# 10783              80           1.000000e-07                 6
# 10784              80           1.000000e-07                 8
# 10785              80           1.000000e-07                 8
# 10786              80           1.000000e-07                10
# 10787              80           1.000000e-07                10
# 10788              90           1.000000e-07                 1
# 10789              90           1.000000e-07                 1
# 10790              90           1.000000e-07                 2
# 10791              90           1.000000e-07                 2
# 10792              90           1.000000e-07                 4
# 10793              90           1.000000e-07                 4
# 10794              90           1.000000e-07                 6
# 10795              90           1.000000e-07                 6
# 10796              90           1.000000e-07                 8
# 10797              90           1.000000e-07                 8
# 10798              90           1.000000e-07                10
# 10799              90           1.000000e-07                10
#
#        min_samples_split  min_weight_fraction_leaf  presort  random_state  \
# 0                      2                       0.0    False           NaN
# 1                      2                       0.0    False           NaN
# 2                      2                       0.0    False           NaN
# 3                      2                       0.0    False           NaN
# 4                      2                       0.0    False           NaN
# 5                      2                       0.0    False           NaN
# 6                      2                       0.0    False           NaN
# 7                      2                       0.0    False           NaN
# 8                      2                       0.0    False           NaN
# 9                      2                       0.0    False           NaN
# 10                     2                       0.0    False           NaN
# 11                     2                       0.0    False           NaN
# 12                     2                       0.0    False           NaN
# 13                     2                       0.0    False           NaN
# 14                     2                       0.0    False           NaN
# 15                     2                       0.0    False           NaN
# 16                     2                       0.0    False           NaN
# 17                     2                       0.0    False           NaN
# 18                     2                       0.0    False           NaN
# 19                     2                       0.0    False           NaN
# 20                     2                       0.0    False           NaN
# 21                     2                       0.0    False           NaN
# 22                     2                       0.0    False           NaN
# 23                     2                       0.0    False           NaN
# 24                     2                       0.0    False           NaN
# 25                     2                       0.0    False           NaN
# 26                     2                       0.0    False           NaN
# 27                     2                       0.0    False           NaN
# 28                     2                       0.0    False           NaN
# 29                     2                       0.0    False           NaN
# ...                  ...                       ...      ...           ...
# 10770                  2                       0.0    False           NaN
# 10771                  2                       0.0    False           NaN
# 10772                  2                       0.0    False           NaN
# 10773                  2                       0.0    False           NaN
# 10774                  2                       0.0    False           NaN
# 10775                  2                       0.0    False           NaN
# 10776                  2                       0.0    False           NaN
# 10777                  2                       0.0    False           NaN
# 10778                  2                       0.0    False           NaN
# 10779                  2                       0.0    False           NaN
# 10780                  2                       0.0    False           NaN
# 10781                  2                       0.0    False           NaN
# 10782                  2                       0.0    False           NaN
# 10783                  2                       0.0    False           NaN
# 10784                  2                       0.0    False           NaN
# 10785                  2                       0.0    False           NaN
# 10786                  2                       0.0    False           NaN
# 10787                  2                       0.0    False           NaN
# 10788                  2                       0.0    False           NaN
# 10789                  2                       0.0    False           NaN
# 10790                  2                       0.0    False           NaN
# 10791                  2                       0.0    False           NaN
# 10792                  2                       0.0    False           NaN
# 10793                  2                       0.0    False           NaN
# 10794                  2                       0.0    False           NaN
# 10795                  2                       0.0    False           NaN
# 10796                  2                       0.0    False           NaN
# 10797                  2                       0.0    False           NaN
# 10798                  2                       0.0    False           NaN
# 10799                  2                       0.0    False           NaN
#
#                                               results splitter
# 0              ./data2/Apache-0001-classification.csv     best
# 1                  ./data2/Apache-0001-regression.csv     best
# 2              ./data2/Apache-0002-classification.csv     best
# 3                  ./data2/Apache-0002-regression.csv     best
# 4              ./data2/Apache-0003-classification.csv     best
# 5                  ./data2/Apache-0003-regression.csv     best
# 6              ./data2/Apache-0004-classification.csv     best
# 7                  ./data2/Apache-0004-regression.csv     best
# 8              ./data2/Apache-0005-classification.csv     best
# 9                  ./data2/Apache-0005-regression.csv     best
# 10             ./data2/Apache-0006-classification.csv     best
# 11                 ./data2/Apache-0006-regression.csv     best
# 12             ./data2/Apache-0007-classification.csv     best
# 13                 ./data2/Apache-0007-regression.csv     best
# 14             ./data2/Apache-0008-classification.csv     best
# 15                 ./data2/Apache-0008-regression.csv     best
# 16             ./data2/Apache-0009-classification.csv     best
# 17                 ./data2/Apache-0009-regression.csv     best
# 18             ./data2/Apache-0010-classification.csv     best
# 19                 ./data2/Apache-0010-regression.csv     best
# 20             ./data2/Apache-0011-classification.csv     best
# 21                 ./data2/Apache-0011-regression.csv     best
# 22             ./data2/Apache-0012-classification.csv     best
# 23                 ./data2/Apache-0012-regression.csv     best
# 24             ./data2/Apache-0013-classification.csv     best
# 25                 ./data2/Apache-0013-regression.csv     best
# 26             ./data2/Apache-0014-classification.csv     best
# 27                 ./data2/Apache-0014-regression.csv     best
# 28             ./data2/Apache-0015-classification.csv     best
# 29                 ./data2/Apache-0015-regression.csv     best
# ...                                               ...      ...
# 10770  ./data2/HIPAcc-1066-classification_strat_6.csv     best
# 10771  ./data2/HIPAcc-1066-classification_strat_8.csv     best
# 10772  ./data2/HIPAcc-1067-classification_strat_6.csv     best
# 10773  ./data2/HIPAcc-1067-classification_strat_8.csv     best
# 10774  ./data2/HIPAcc-1068-classification_strat_6.csv     best
# 10775  ./data2/HIPAcc-1068-classification_strat_8.csv     best
# 10776  ./data2/HIPAcc-1069-classification_strat_6.csv     best
# 10777  ./data2/HIPAcc-1069-classification_strat_8.csv     best
# 10778  ./data2/HIPAcc-1070-classification_strat_6.csv     best
# 10779  ./data2/HIPAcc-1070-classification_strat_8.csv     best
# 10780  ./data2/HIPAcc-1071-classification_strat_6.csv     best
# 10781  ./data2/HIPAcc-1071-classification_strat_8.csv     best
# 10782  ./data2/HIPAcc-1072-classification_strat_6.csv     best
# 10783  ./data2/HIPAcc-1072-classification_strat_8.csv     best
# 10784  ./data2/HIPAcc-1073-classification_strat_6.csv     best
# 10785  ./data2/HIPAcc-1073-classification_strat_8.csv     best
# 10786  ./data2/HIPAcc-1074-classification_strat_6.csv     best
# 10787  ./data2/HIPAcc-1074-classification_strat_8.csv     best
# 10788  ./data2/HIPAcc-1075-classification_strat_6.csv     best
# 10789  ./data2/HIPAcc-1075-classification_strat_8.csv     best
# 10790  ./data2/HIPAcc-1076-classification_strat_6.csv     best
# 10791  ./data2/HIPAcc-1076-classification_strat_8.csv     best
# 10792  ./data2/HIPAcc-1077-classification_strat_6.csv     best
# 10793  ./data2/HIPAcc-1077-classification_strat_8.csv     best
# 10794  ./data2/HIPAcc-1078-classification_strat_6.csv     best
# 10795  ./data2/HIPAcc-1078-classification_strat_8.csv     best
# 10796  ./data2/HIPAcc-1079-classification_strat_6.csv     best
# 10797  ./data2/HIPAcc-1079-classification_strat_8.csv     best
# 10798  ./data2/HIPAcc-1080-classification_strat_6.csv     best
# 10799  ./data2/HIPAcc-1080-classification_strat_8.csv     best
#
# [10800 rows x 14 columns]

# %%
serie = []
for i in resultsList['results']:
    serie.append(i.split("-")[2].split(".")[0])

serie = pd.Series(serie)

resultsList['type'] = serie

# %%
accuracy = []
mse = []
for i in resultsList['results']:
    dfTemp = pd.read_csv(i)
    dfMean = dfTemp.groupby(['sr']).mean().drop(['t'],axis=1)
    dfMean['accuracy']= (dfMean['TP']+dfMean['TN']) / (dfMean['TP']+dfMean['TN']+dfMean['FN']+dfMean['FP'])
    accuracy.append(dfMean['accuracy'].mean())
    if 'MSE' in dfMean.columns:
        mse.append(dfMean['MSE'].mean())
    else:
        mse.append(None)
resultsList['mse'] = pd.Series(mse)
resultsList['accuracy'] = pd.Series(accuracy)

idx = resultsList.groupby(["file","type"])["accuracy"].transform(max) == resultsList['accuracy']
resultsList[idx].sort_values(["file"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib64/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MSE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-375-c2d66b9f3dcd> in <module>()
#       6     dfMean['accuracy']= (dfMean['TP']+dfMean['TN']) / (dfMean['TP']+dfMean['TN']+dfMean['FN']+dfMean['FP'])
#       7     accuracy.append(dfMean['accuracy'].mean())
# ----> 8     mse.append(dfMean['MSE'].mean())
#       9 resultsList['mse'] = pd.Series(mse)
#      10 resultsList['accuracy'] = pd.Series(accuracy)
#
# /usr/lib64/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /usr/lib64/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /usr/lib64/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /usr/lib64/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /usr/lib64/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MSE'

# %%
resultsReg = resultsList[resultsList["type"] == "regression"]

# %%
mse = []
for i in resultsReg['results']:
    dfTemp = pd.read_csv(i)
    dfMean = dfTemp.groupby(['sr']).mean().drop(['t'],axis=1)
    mse.append(dfMean['MSE'].mean())
resultsReg['mse'] = pd.Series(mse)
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
resultsList
# Out:
#        class_weight criterion    file  max_depth  max_features  \
# 0               NaN   entropy  Apache        NaN           NaN
# 1               NaN       mse  Apache        NaN           NaN
# 2               NaN   entropy  Apache        NaN           NaN
# 3               NaN       mse  Apache        NaN           NaN
# 4               NaN   entropy  Apache        NaN           NaN
# 5               NaN       mse  Apache        NaN           NaN
# 6               NaN   entropy  Apache        NaN           NaN
# 7               NaN       mse  Apache        NaN           NaN
# 8               NaN   entropy  Apache        NaN           NaN
# 9               NaN       mse  Apache        NaN           NaN
# 10              NaN   entropy  Apache        NaN           NaN
# 11              NaN       mse  Apache        NaN           NaN
# 12              NaN   entropy  Apache        NaN           NaN
# 13              NaN       mse  Apache        NaN           NaN
# 14              NaN   entropy  Apache        NaN           NaN
# 15              NaN       mse  Apache        NaN           NaN
# 16              NaN   entropy  Apache        NaN           NaN
# 17              NaN       mse  Apache        NaN           NaN
# 18              NaN   entropy  Apache        NaN           NaN
# 19              NaN       mse  Apache        NaN           NaN
# 20              NaN   entropy  Apache        NaN           NaN
# 21              NaN       mse  Apache        NaN           NaN
# 22              NaN   entropy  Apache        NaN           NaN
# 23              NaN       mse  Apache        NaN           NaN
# 24              NaN   entropy  Apache        NaN           NaN
# 25              NaN       mse  Apache        NaN           NaN
# 26              NaN   entropy  Apache        NaN           NaN
# 27              NaN       mse  Apache        NaN           NaN
# 28              NaN   entropy  Apache        NaN           NaN
# 29              NaN       mse  Apache        NaN           NaN
# ...             ...       ...     ...        ...           ...
# 10770           NaN   entropy  HIPAcc       90.0           NaN
# 10771           NaN   entropy  HIPAcc       90.0           NaN
# 10772           NaN   entropy  HIPAcc       90.0           NaN
# 10773           NaN   entropy  HIPAcc       90.0           NaN
# 10774           NaN   entropy  HIPAcc       90.0           NaN
# 10775           NaN   entropy  HIPAcc       90.0           NaN
# 10776           NaN   entropy  HIPAcc       90.0           NaN
# 10777           NaN   entropy  HIPAcc       90.0           NaN
# 10778           NaN   entropy  HIPAcc       90.0           NaN
# 10779           NaN   entropy  HIPAcc       90.0           NaN
# 10780           NaN   entropy  HIPAcc       90.0           NaN
# 10781           NaN   entropy  HIPAcc       90.0           NaN
# 10782           NaN   entropy  HIPAcc       90.0           NaN
# 10783           NaN   entropy  HIPAcc       90.0           NaN
# 10784           NaN   entropy  HIPAcc       90.0           NaN
# 10785           NaN   entropy  HIPAcc       90.0           NaN
# 10786           NaN   entropy  HIPAcc       90.0           NaN
# 10787           NaN   entropy  HIPAcc       90.0           NaN
# 10788           NaN   entropy  HIPAcc       90.0           NaN
# 10789           NaN   entropy  HIPAcc       90.0           NaN
# 10790           NaN   entropy  HIPAcc       90.0           NaN
# 10791           NaN   entropy  HIPAcc       90.0           NaN
# 10792           NaN   entropy  HIPAcc       90.0           NaN
# 10793           NaN   entropy  HIPAcc       90.0           NaN
# 10794           NaN   entropy  HIPAcc       90.0           NaN
# 10795           NaN   entropy  HIPAcc       90.0           NaN
# 10796           NaN   entropy  HIPAcc       90.0           NaN
# 10797           NaN   entropy  HIPAcc       90.0           NaN
# 10798           NaN   entropy  HIPAcc       90.0           NaN
# 10799           NaN   entropy  HIPAcc       90.0           NaN
#
#        max_leaf_nodes  min_impurity_decrease  min_samples_leaf  \
# 0                  10           1.000000e-07                 1
# 1                  10           1.000000e-07                 1
# 2                  10           1.000000e-07                 2
# 3                  10           1.000000e-07                 2
# 4                  10           1.000000e-07                 4
# 5                  10           1.000000e-07                 4
# 6                  10           1.000000e-07                 6
# 7                  10           1.000000e-07                 6
# 8                  10           1.000000e-07                 8
# 9                  10           1.000000e-07                 8
# 10                 10           1.000000e-07                10
# 11                 10           1.000000e-07                10
# 12                 20           1.000000e-07                 1
# 13                 20           1.000000e-07                 1
# 14                 20           1.000000e-07                 2
# 15                 20           1.000000e-07                 2
# 16                 20           1.000000e-07                 4
# 17                 20           1.000000e-07                 4
# 18                 20           1.000000e-07                 6
# 19                 20           1.000000e-07                 6
# 20                 20           1.000000e-07                 8
# 21                 20           1.000000e-07                 8
# 22                 20           1.000000e-07                10
# 23                 20           1.000000e-07                10
# 24                 30           1.000000e-07                 1
# 25                 30           1.000000e-07                 1
# 26                 30           1.000000e-07                 2
# 27                 30           1.000000e-07                 2
# 28                 30           1.000000e-07                 4
# 29                 30           1.000000e-07                 4
# ...               ...                    ...               ...
# 10770              70           1.000000e-07                 6
# 10771              70           1.000000e-07                 6
# 10772              70           1.000000e-07                 8
# 10773              70           1.000000e-07                 8
# 10774              70           1.000000e-07                10
# 10775              70           1.000000e-07                10
# 10776              80           1.000000e-07                 1
# 10777              80           1.000000e-07                 1
# 10778              80           1.000000e-07                 2
# 10779              80           1.000000e-07                 2
# 10780              80           1.000000e-07                 4
# 10781              80           1.000000e-07                 4
# 10782              80           1.000000e-07                 6
# 10783              80           1.000000e-07                 6
# 10784              80           1.000000e-07                 8
# 10785              80           1.000000e-07                 8
# 10786              80           1.000000e-07                10
# 10787              80           1.000000e-07                10
# 10788              90           1.000000e-07                 1
# 10789              90           1.000000e-07                 1
# 10790              90           1.000000e-07                 2
# 10791              90           1.000000e-07                 2
# 10792              90           1.000000e-07                 4
# 10793              90           1.000000e-07                 4
# 10794              90           1.000000e-07                 6
# 10795              90           1.000000e-07                 6
# 10796              90           1.000000e-07                 8
# 10797              90           1.000000e-07                 8
# 10798              90           1.000000e-07                10
# 10799              90           1.000000e-07                10
#
#        min_samples_split  min_weight_fraction_leaf  presort  random_state  \
# 0                      2                       0.0    False           NaN
# 1                      2                       0.0    False           NaN
# 2                      2                       0.0    False           NaN
# 3                      2                       0.0    False           NaN
# 4                      2                       0.0    False           NaN
# 5                      2                       0.0    False           NaN
# 6                      2                       0.0    False           NaN
# 7                      2                       0.0    False           NaN
# 8                      2                       0.0    False           NaN
# 9                      2                       0.0    False           NaN
# 10                     2                       0.0    False           NaN
# 11                     2                       0.0    False           NaN
# 12                     2                       0.0    False           NaN
# 13                     2                       0.0    False           NaN
# 14                     2                       0.0    False           NaN
# 15                     2                       0.0    False           NaN
# 16                     2                       0.0    False           NaN
# 17                     2                       0.0    False           NaN
# 18                     2                       0.0    False           NaN
# 19                     2                       0.0    False           NaN
# 20                     2                       0.0    False           NaN
# 21                     2                       0.0    False           NaN
# 22                     2                       0.0    False           NaN
# 23                     2                       0.0    False           NaN
# 24                     2                       0.0    False           NaN
# 25                     2                       0.0    False           NaN
# 26                     2                       0.0    False           NaN
# 27                     2                       0.0    False           NaN
# 28                     2                       0.0    False           NaN
# 29                     2                       0.0    False           NaN
# ...                  ...                       ...      ...           ...
# 10770                  2                       0.0    False           NaN
# 10771                  2                       0.0    False           NaN
# 10772                  2                       0.0    False           NaN
# 10773                  2                       0.0    False           NaN
# 10774                  2                       0.0    False           NaN
# 10775                  2                       0.0    False           NaN
# 10776                  2                       0.0    False           NaN
# 10777                  2                       0.0    False           NaN
# 10778                  2                       0.0    False           NaN
# 10779                  2                       0.0    False           NaN
# 10780                  2                       0.0    False           NaN
# 10781                  2                       0.0    False           NaN
# 10782                  2                       0.0    False           NaN
# 10783                  2                       0.0    False           NaN
# 10784                  2                       0.0    False           NaN
# 10785                  2                       0.0    False           NaN
# 10786                  2                       0.0    False           NaN
# 10787                  2                       0.0    False           NaN
# 10788                  2                       0.0    False           NaN
# 10789                  2                       0.0    False           NaN
# 10790                  2                       0.0    False           NaN
# 10791                  2                       0.0    False           NaN
# 10792                  2                       0.0    False           NaN
# 10793                  2                       0.0    False           NaN
# 10794                  2                       0.0    False           NaN
# 10795                  2                       0.0    False           NaN
# 10796                  2                       0.0    False           NaN
# 10797                  2                       0.0    False           NaN
# 10798                  2                       0.0    False           NaN
# 10799                  2                       0.0    False           NaN
#
#                                               results splitter  \
# 0              ./data2/Apache-0001-classification.csv     best
# 1                  ./data2/Apache-0001-regression.csv     best
# 2              ./data2/Apache-0002-classification.csv     best
# 3                  ./data2/Apache-0002-regression.csv     best
# 4              ./data2/Apache-0003-classification.csv     best
# 5                  ./data2/Apache-0003-regression.csv     best
# 6              ./data2/Apache-0004-classification.csv     best
# 7                  ./data2/Apache-0004-regression.csv     best
# 8              ./data2/Apache-0005-classification.csv     best
# 9                  ./data2/Apache-0005-regression.csv     best
# 10             ./data2/Apache-0006-classification.csv     best
# 11                 ./data2/Apache-0006-regression.csv     best
# 12             ./data2/Apache-0007-classification.csv     best
# 13                 ./data2/Apache-0007-regression.csv     best
# 14             ./data2/Apache-0008-classification.csv     best
# 15                 ./data2/Apache-0008-regression.csv     best
# 16             ./data2/Apache-0009-classification.csv     best
# 17                 ./data2/Apache-0009-regression.csv     best
# 18             ./data2/Apache-0010-classification.csv     best
# 19                 ./data2/Apache-0010-regression.csv     best
# 20             ./data2/Apache-0011-classification.csv     best
# 21                 ./data2/Apache-0011-regression.csv     best
# 22             ./data2/Apache-0012-classification.csv     best
# 23                 ./data2/Apache-0012-regression.csv     best
# 24             ./data2/Apache-0013-classification.csv     best
# 25                 ./data2/Apache-0013-regression.csv     best
# 26             ./data2/Apache-0014-classification.csv     best
# 27                 ./data2/Apache-0014-regression.csv     best
# 28             ./data2/Apache-0015-classification.csv     best
# 29                 ./data2/Apache-0015-regression.csv     best
# ...                                               ...      ...
# 10770  ./data2/HIPAcc-1066-classification_strat_6.csv     best
# 10771  ./data2/HIPAcc-1066-classification_strat_8.csv     best
# 10772  ./data2/HIPAcc-1067-classification_strat_6.csv     best
# 10773  ./data2/HIPAcc-1067-classification_strat_8.csv     best
# 10774  ./data2/HIPAcc-1068-classification_strat_6.csv     best
# 10775  ./data2/HIPAcc-1068-classification_strat_8.csv     best
# 10776  ./data2/HIPAcc-1069-classification_strat_6.csv     best
# 10777  ./data2/HIPAcc-1069-classification_strat_8.csv     best
# 10778  ./data2/HIPAcc-1070-classification_strat_6.csv     best
# 10779  ./data2/HIPAcc-1070-classification_strat_8.csv     best
# 10780  ./data2/HIPAcc-1071-classification_strat_6.csv     best
# 10781  ./data2/HIPAcc-1071-classification_strat_8.csv     best
# 10782  ./data2/HIPAcc-1072-classification_strat_6.csv     best
# 10783  ./data2/HIPAcc-1072-classification_strat_8.csv     best
# 10784  ./data2/HIPAcc-1073-classification_strat_6.csv     best
# 10785  ./data2/HIPAcc-1073-classification_strat_8.csv     best
# 10786  ./data2/HIPAcc-1074-classification_strat_6.csv     best
# 10787  ./data2/HIPAcc-1074-classification_strat_8.csv     best
# 10788  ./data2/HIPAcc-1075-classification_strat_6.csv     best
# 10789  ./data2/HIPAcc-1075-classification_strat_8.csv     best
# 10790  ./data2/HIPAcc-1076-classification_strat_6.csv     best
# 10791  ./data2/HIPAcc-1076-classification_strat_8.csv     best
# 10792  ./data2/HIPAcc-1077-classification_strat_6.csv     best
# 10793  ./data2/HIPAcc-1077-classification_strat_8.csv     best
# 10794  ./data2/HIPAcc-1078-classification_strat_6.csv     best
# 10795  ./data2/HIPAcc-1078-classification_strat_8.csv     best
# 10796  ./data2/HIPAcc-1079-classification_strat_6.csv     best
# 10797  ./data2/HIPAcc-1079-classification_strat_8.csv     best
# 10798  ./data2/HIPAcc-1080-classification_strat_6.csv     best
# 10799  ./data2/HIPAcc-1080-classification_strat_8.csv     best
#
#                          type
# 0              classification
# 1                  regression
# 2              classification
# 3                  regression
# 4              classification
# 5                  regression
# 6              classification
# 7                  regression
# 8              classification
# 9                  regression
# 10             classification
# 11                 regression
# 12             classification
# 13                 regression
# 14             classification
# 15                 regression
# 16             classification
# 17                 regression
# 18             classification
# 19                 regression
# 20             classification
# 21                 regression
# 22             classification
# 23                 regression
# 24             classification
# 25                 regression
# 26             classification
# 27                 regression
# 28             classification
# 29                 regression
# ...                       ...
# 10770  classification_strat_6
# 10771  classification_strat_8
# 10772  classification_strat_6
# 10773  classification_strat_8
# 10774  classification_strat_6
# 10775  classification_strat_8
# 10776  classification_strat_6
# 10777  classification_strat_8
# 10778  classification_strat_6
# 10779  classification_strat_8
# 10780  classification_strat_6
# 10781  classification_strat_8
# 10782  classification_strat_6
# 10783  classification_strat_8
# 10784  classification_strat_6
# 10785  classification_strat_8
# 10786  classification_strat_6
# 10787  classification_strat_8
# 10788  classification_strat_6
# 10789  classification_strat_8
# 10790  classification_strat_6
# 10791  classification_strat_8
# 10792  classification_strat_6
# 10793  classification_strat_8
# 10794  classification_strat_6
# 10795  classification_strat_8
# 10796  classification_strat_6
# 10797  classification_strat_8
# 10798  classification_strat_6
# 10799  classification_strat_8
#
# [10800 rows x 15 columns]

# %%
resultsList['mse']
# Out:
# 1       4164.336543
# 3       5267.730159
# 5       8379.001473
# 7       4223.073191
# 9       5507.075927
# 11      7633.493826
# 13      3526.625614
# 15      5399.897271
# 17      7058.876356
# 19      4246.978798
# 21      5588.710637
# 23      7081.068286
# 25      4517.172396
# 27      5669.959684
# 29      7348.982446
# 31      3403.942253
# 33      5197.334063
# 35      7124.561785
# 37      3762.858363
# 39      5377.250204
# 41      8128.986575
# 43      3194.317135
# 45      5705.862719
# 47      7332.628040
# 49      3837.470526
# 51      5844.784981
# 53      7607.043671
# 55      3695.277076
# 57      5146.843354
# 59      7184.035274
#            ...
# 5341            NaN
# 5343            NaN
# 5345            NaN
# 5347            NaN
# 5349            NaN
# 5351            NaN
# 5353            NaN
# 5355            NaN
# 5357            NaN
# 5359            NaN
# 5361            NaN
# 5363            NaN
# 5365            NaN
# 5367            NaN
# 5369            NaN
# 5371            NaN
# 5373            NaN
# 5375            NaN
# 5377            NaN
# 5379            NaN
# 5381            NaN
# 5383            NaN
# 5385            NaN
# 5387            NaN
# 5389            NaN
# 5391            NaN
# 5393            NaN
# 5395            NaN
# 5397            NaN
# 5399            NaN
# Name: mse, Length: 2700, dtype: float64
