# %%
import pandas as pd

resultsList = pd.read_csv("./data/results-list.csv")

# %%
resultsList
# Out:
#       class_weight criterion     file  max_depth  max_features  \
# 0              NaN   entropy  dataset        NaN           NaN
# 1              NaN       mse  dataset        NaN           NaN
# 2              NaN   entropy  dataset        NaN           NaN
# 3              NaN       mse  dataset        NaN           NaN
# 4              NaN   entropy  dataset        NaN           NaN
# 5              NaN       mse  dataset        NaN           NaN
# 6              NaN   entropy  dataset        NaN           NaN
# 7              NaN       mse  dataset        NaN           NaN
# 8              NaN   entropy  dataset        NaN           NaN
# 9              NaN       mse  dataset        NaN           NaN
# 10             NaN   entropy  dataset        NaN           NaN
# 11             NaN       mse  dataset        NaN           NaN
# 12             NaN   entropy  dataset        NaN           NaN
# 13             NaN       mse  dataset        NaN           NaN
# 14             NaN   entropy  dataset        NaN           NaN
# 15             NaN       mse  dataset        NaN           NaN
# 16             NaN   entropy  dataset        NaN           NaN
# 17             NaN       mse  dataset        NaN           NaN
# 18             NaN   entropy  dataset        NaN           NaN
# 19             NaN       mse  dataset        NaN           NaN
# 20             NaN   entropy  dataset        NaN           NaN
# 21             NaN       mse  dataset        NaN           NaN
# 22             NaN   entropy  dataset        NaN           NaN
# 23             NaN       mse  dataset        NaN           NaN
# 24             NaN   entropy  dataset        NaN           NaN
# 25             NaN       mse  dataset        NaN           NaN
# 26             NaN   entropy  dataset        NaN           NaN
# 27             NaN       mse  dataset        NaN           NaN
# 28             NaN   entropy  dataset        NaN           NaN
# 29             NaN       mse  dataset        NaN           NaN
# ...            ...       ...      ...        ...           ...
# 1050           NaN   entropy  dataset       90.0           NaN
# 1051           NaN       mse  dataset       90.0           NaN
# 1052           NaN   entropy  dataset       90.0           NaN
# 1053           NaN       mse  dataset       90.0           NaN
# 1054           NaN   entropy  dataset       90.0           NaN
# 1055           NaN       mse  dataset       90.0           NaN
# 1056           NaN   entropy  dataset       90.0           NaN
# 1057           NaN       mse  dataset       90.0           NaN
# 1058           NaN   entropy  dataset       90.0           NaN
# 1059           NaN       mse  dataset       90.0           NaN
# 1060           NaN   entropy  dataset       90.0           NaN
# 1061           NaN       mse  dataset       90.0           NaN
# 1062           NaN   entropy  dataset       90.0           NaN
# 1063           NaN       mse  dataset       90.0           NaN
# 1064           NaN   entropy  dataset       90.0           NaN
# 1065           NaN       mse  dataset       90.0           NaN
# 1066           NaN   entropy  dataset       90.0           NaN
# 1067           NaN       mse  dataset       90.0           NaN
# 1068           NaN   entropy  dataset       90.0           NaN
# 1069           NaN       mse  dataset       90.0           NaN
# 1070           NaN   entropy  dataset       90.0           NaN
# 1071           NaN       mse  dataset       90.0           NaN
# 1072           NaN   entropy  dataset       90.0           NaN
# 1073           NaN       mse  dataset       90.0           NaN
# 1074           NaN   entropy  dataset       90.0           NaN
# 1075           NaN       mse  dataset       90.0           NaN
# 1076           NaN   entropy  dataset       90.0           NaN
# 1077           NaN       mse  dataset       90.0           NaN
# 1078           NaN   entropy  dataset       90.0           NaN
# 1079           NaN       mse  dataset       90.0           NaN
#
#       max_leaf_nodes  min_impurity_decrease  min_samples_leaf  \
# 0                 10           1.000000e-07                 1
# 1                 10           1.000000e-07                 1
# 2                 10           1.000000e-07                 2
# 3                 10           1.000000e-07                 2
# 4                 10           1.000000e-07                 4
# 5                 10           1.000000e-07                 4
# 6                 10           1.000000e-07                 6
# 7                 10           1.000000e-07                 6
# 8                 10           1.000000e-07                 8
# 9                 10           1.000000e-07                 8
# 10                10           1.000000e-07                10
# 11                10           1.000000e-07                10
# 12                20           1.000000e-07                 1
# 13                20           1.000000e-07                 1
# 14                20           1.000000e-07                 2
# 15                20           1.000000e-07                 2
# 16                20           1.000000e-07                 4
# 17                20           1.000000e-07                 4
# 18                20           1.000000e-07                 6
# 19                20           1.000000e-07                 6
# 20                20           1.000000e-07                 8
# 21                20           1.000000e-07                 8
# 22                20           1.000000e-07                10
# 23                20           1.000000e-07                10
# 24                30           1.000000e-07                 1
# 25                30           1.000000e-07                 1
# 26                30           1.000000e-07                 2
# 27                30           1.000000e-07                 2
# 28                30           1.000000e-07                 4
# 29                30           1.000000e-07                 4
# ...              ...                    ...               ...
# 1050              70           1.000000e-07                 6
# 1051              70           1.000000e-07                 6
# 1052              70           1.000000e-07                 8
# 1053              70           1.000000e-07                 8
# 1054              70           1.000000e-07                10
# 1055              70           1.000000e-07                10
# 1056              80           1.000000e-07                 1
# 1057              80           1.000000e-07                 1
# 1058              80           1.000000e-07                 2
# 1059              80           1.000000e-07                 2
# 1060              80           1.000000e-07                 4
# 1061              80           1.000000e-07                 4
# 1062              80           1.000000e-07                 6
# 1063              80           1.000000e-07                 6
# 1064              80           1.000000e-07                 8
# 1065              80           1.000000e-07                 8
# 1066              80           1.000000e-07                10
# 1067              80           1.000000e-07                10
# 1068              90           1.000000e-07                 1
# 1069              90           1.000000e-07                 1
# 1070              90           1.000000e-07                 2
# 1071              90           1.000000e-07                 2
# 1072              90           1.000000e-07                 4
# 1073              90           1.000000e-07                 4
# 1074              90           1.000000e-07                 6
# 1075              90           1.000000e-07                 6
# 1076              90           1.000000e-07                 8
# 1077              90           1.000000e-07                 8
# 1078              90           1.000000e-07                10
# 1079              90           1.000000e-07                10
#
#       min_samples_split  min_weight_fraction_leaf  presort  random_state  \
# 0                     2                       0.0    False           NaN
# 1                     2                       0.0    False           NaN
# 2                     2                       0.0    False           NaN
# 3                     2                       0.0    False           NaN
# 4                     2                       0.0    False           NaN
# 5                     2                       0.0    False           NaN
# 6                     2                       0.0    False           NaN
# 7                     2                       0.0    False           NaN
# 8                     2                       0.0    False           NaN
# 9                     2                       0.0    False           NaN
# 10                    2                       0.0    False           NaN
# 11                    2                       0.0    False           NaN
# 12                    2                       0.0    False           NaN
# 13                    2                       0.0    False           NaN
# 14                    2                       0.0    False           NaN
# 15                    2                       0.0    False           NaN
# 16                    2                       0.0    False           NaN
# 17                    2                       0.0    False           NaN
# 18                    2                       0.0    False           NaN
# 19                    2                       0.0    False           NaN
# 20                    2                       0.0    False           NaN
# 21                    2                       0.0    False           NaN
# 22                    2                       0.0    False           NaN
# 23                    2                       0.0    False           NaN
# 24                    2                       0.0    False           NaN
# 25                    2                       0.0    False           NaN
# 26                    2                       0.0    False           NaN
# 27                    2                       0.0    False           NaN
# 28                    2                       0.0    False           NaN
# 29                    2                       0.0    False           NaN
# ...                 ...                       ...      ...           ...
# 1050                  2                       0.0    False           NaN
# 1051                  2                       0.0    False           NaN
# 1052                  2                       0.0    False           NaN
# 1053                  2                       0.0    False           NaN
# 1054                  2                       0.0    False           NaN
# 1055                  2                       0.0    False           NaN
# 1056                  2                       0.0    False           NaN
# 1057                  2                       0.0    False           NaN
# 1058                  2                       0.0    False           NaN
# 1059                  2                       0.0    False           NaN
# 1060                  2                       0.0    False           NaN
# 1061                  2                       0.0    False           NaN
# 1062                  2                       0.0    False           NaN
# 1063                  2                       0.0    False           NaN
# 1064                  2                       0.0    False           NaN
# 1065                  2                       0.0    False           NaN
# 1066                  2                       0.0    False           NaN
# 1067                  2                       0.0    False           NaN
# 1068                  2                       0.0    False           NaN
# 1069                  2                       0.0    False           NaN
# 1070                  2                       0.0    False           NaN
# 1071                  2                       0.0    False           NaN
# 1072                  2                       0.0    False           NaN
# 1073                  2                       0.0    False           NaN
# 1074                  2                       0.0    False           NaN
# 1075                  2                       0.0    False           NaN
# 1076                  2                       0.0    False           NaN
# 1077                  2                       0.0    False           NaN
# 1078                  2                       0.0    False           NaN
# 1079                  2                       0.0    False           NaN
#
#                                    results splitter
# 0     ./data/video-0001-classification.csv     best
# 1         ./data/video-0001-regression.csv     best
# 2     ./data/video-0002-classification.csv     best
# 3         ./data/video-0002-regression.csv     best
# 4     ./data/video-0003-classification.csv     best
# 5         ./data/video-0003-regression.csv     best
# 6     ./data/video-0004-classification.csv     best
# 7         ./data/video-0004-regression.csv     best
# 8     ./data/video-0005-classification.csv     best
# 9         ./data/video-0005-regression.csv     best
# 10    ./data/video-0006-classification.csv     best
# 11        ./data/video-0006-regression.csv     best
# 12    ./data/video-0007-classification.csv     best
# 13        ./data/video-0007-regression.csv     best
# 14    ./data/video-0008-classification.csv     best
# 15        ./data/video-0008-regression.csv     best
# 16    ./data/video-0009-classification.csv     best
# 17        ./data/video-0009-regression.csv     best
# 18    ./data/video-0010-classification.csv     best
# 19        ./data/video-0010-regression.csv     best
# 20    ./data/video-0011-classification.csv     best
# 21        ./data/video-0011-regression.csv     best
# 22    ./data/video-0012-classification.csv     best
# 23        ./data/video-0012-regression.csv     best
# 24    ./data/video-0013-classification.csv     best
# 25        ./data/video-0013-regression.csv     best
# 26    ./data/video-0014-classification.csv     best
# 27        ./data/video-0014-regression.csv     best
# 28    ./data/video-0015-classification.csv     best
# 29        ./data/video-0015-regression.csv     best
# ...                                    ...      ...
# 1050  ./data/video-0526-classification.csv     best
# 1051      ./data/video-0526-regression.csv     best
# 1052  ./data/video-0527-classification.csv     best
# 1053      ./data/video-0527-regression.csv     best
# 1054  ./data/video-0528-classification.csv     best
# 1055      ./data/video-0528-regression.csv     best
# 1056  ./data/video-0529-classification.csv     best
# 1057      ./data/video-0529-regression.csv     best
# 1058  ./data/video-0530-classification.csv     best
# 1059      ./data/video-0530-regression.csv     best
# 1060  ./data/video-0531-classification.csv     best
# 1061      ./data/video-0531-regression.csv     best
# 1062  ./data/video-0532-classification.csv     best
# 1063      ./data/video-0532-regression.csv     best
# 1064  ./data/video-0533-classification.csv     best
# 1065      ./data/video-0533-regression.csv     best
# 1066  ./data/video-0534-classification.csv     best
# 1067      ./data/video-0534-regression.csv     best
# 1068  ./data/video-0535-classification.csv     best
# 1069      ./data/video-0535-regression.csv     best
# 1070  ./data/video-0536-classification.csv     best
# 1071      ./data/video-0536-regression.csv     best
# 1072  ./data/video-0537-classification.csv     best
# 1073      ./data/video-0537-regression.csv     best
# 1074  ./data/video-0538-classification.csv     best
# 1075      ./data/video-0538-regression.csv     best
# 1076  ./data/video-0539-classification.csv     best
# 1077      ./data/video-0539-regression.csv     best
# 1078  ./data/video-0540-classification.csv     best
# 1079      ./data/video-0540-regression.csv     best
#
# [1080 rows x 14 columns]

# %%
serie = []
for i in resultsList['results']:
    serie.append(i.split("-")[2].split(".")[0])

serie = pd.Series(serie)

resultsList['type'] = serie

accuracy = []
mse = []
for i in resultsList['results']:
    dfTemp = pd.read_csv(i)
    dfMean = dfTemp.groupby(['sr']).mean()
    dfMean['accuracy']= (dfMean['TP']+dfMean['TN']) / (dfMean['TP']+dfMean['TN']+dfMean['FN']+dfMean['FP'])
    accuracy.append(dfMean['accuracy'].mean())
    if 'MSE' in dfMean.columns:
        mse.append(dfMean['MSE'].mean())
    else:
        mse.append(None)
resultsList['mse'] = pd.Series(mse)
resultsList['accuracy'] = pd.Series(accuracy)

idx = resultsList.groupby(["file","type"])["accuracy"].transform(max) == resultsList['accuracy']
resultsList[idx].sort_values(["file"])
# Out:
#      class_weight criterion     file  max_depth  max_features  max_leaf_nodes  \
# 122           NaN   entropy  dataset       10.0           NaN              20
# 233           NaN       mse  dataset       20.0           NaN              20
#
#      min_impurity_decrease  min_samples_leaf  min_samples_split  \
# 122           1.000000e-07                 2                  2
# 233           1.000000e-07                 4                  2
#
#      min_weight_fraction_leaf  presort  random_state  \
# 122                       0.0    False           NaN
# 233                       0.0    False           NaN
#
#                                   results splitter            type       mse  \
# 122  ./data/video-0062-classification.csv     best  classification       NaN
# 233      ./data/video-0117-regression.csv     best      regression  0.001809
#
#      accuracy
# 122  0.970486
# 233  0.970663

# %%
configSet = []
resultsList2 = resultsList[idx][(resultsList['type'] == "classification") | (resultsList['type'] == "regression")].where(pd.notnull(resultsList), None)
for f in resultsList2.file.unique():
    for t in resultsList2.type.unique():
        for index, r in resultsList2.loc[(resultsList["file"]==f) & (resultsList2["type"]==t)].sort_values("accuracy", ascending=False)[:10].iterrows():
            configuration = {}
            for i in r.keys():
                if not i in ["results","type","accuracy","file"]:
                    if not (r["type"] == "regression" and i=="class_weight"):
                        configuration[i] = r[i]
            configSet.append({"file":r["file"],"type":r["type"],"configuration":configuration})
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
import numpy as np
from scipy import interp
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn import tree

# %%
d = pd.read_csv("./dataset.csv")
d = d.sort_values(by="perf")

perf="value that led to label"
label="label (0 if usable and 1 if not)"

srm = 100
srM = d.shape[0]
srs = 100
NSUBS = 10

n = d.shape[1] - 2

for sr in [n,2*n,3*n]:
    shuffle_split = StratifiedShuffleSplit(train_size=sr, n_splits=NSUBS)

    classifier = tree.DecisionTreeClassifier(**dfConfig[dfConfig['type'] == "classification"].configuration.values[0])
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    i = 0
    for train, test in shuffle_split.split(d,d[label]):
        #.fit(d.drop([perf,label],axis=1).iloc[train_index], d[perf].iloc[train_index])
        #probas_ = classifier.fit(d.drop([perf,label],axis=1).iloc[train], d[perf].iloc[train]).predict_proba(d.drop([perf,label],axis=1).iloc[test])
        probas_ = classifier.fit(d.drop([perf,label],axis=1).iloc[train], d[label].iloc[train]).predict_proba(d.drop([perf,label],axis=1).iloc[test])
        # Compute ROC curve and area the curve
        fpr, tpr, thresholds = roc_curve(d[label].iloc[test], probas_[:, 1])
        #print(thresholds)
        tprs.append(interp(mean_fpr, fpr, tpr))
        tprs[-1][0] = 0.0
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)
        #plt.plot(fpr, tpr, lw=1, alpha=0.3, label='ROC fold %d (AUC = %0.2f)' % (i, roc_auc))

        i += 1

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    plt.plot(mean_fpr, mean_tpr, color='b',
             label=r'Mean ROC Classification (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
             lw=2, alpha=.8)

    plt.rcParams["figure.figsize"] = [15,9]

    std_tpr = np.std(tprs, axis=0)
    tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
    tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
    #plt.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')

    plt.plot(mean_fpr, tprs_lower, '--', color='b',
             label=r'Mean ROC Classification STD',
             lw=1, alpha=.8)

    plt.plot(mean_fpr, tprs_upper, '--', color='b',
             #label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
             lw=1, alpha=.8)
    '''
    d = pd.read_csv(datasetPath+filename+".csv")

    d["label"] = 0
    d.loc[d["perf"] > threshold, "label"] = 1

    X = d.drop(["perf","label"],axis=1,errors="ignore")
    y = d["perf"]
    y_split = d["label"]'''

    classifier = tree.DecisionTreeRegressor(**dfConfig[dfConfig['type'] == "regression"].configuration.values[0])
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    i = 0
    for train, test in shuffle_split.split(d,d[label]):
        #.fit(d.drop([perf,label],axis=1).iloc[train], d[perf].iloc[train]).predict_proba(d.drop([perf,label],axis=1).iloc[test])
        probas_ = classifier.fit(d.drop([perf,label].iloc[train], d[perf].iloc[train]).predict(d.drop([perf,label].iloc[test]) > t
        # Compute ROC curve and area the curve
        fpr, tpr, thresholds = roc_curve(d[perf].iloc[test] > t, probas_)
        #print(thresholds)
        tprs.append(interp(mean_fpr, fpr, tpr))
        tprs[-1][0] = 0.0
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)
        #plt.plot(fpr, tpr, lw=1, alpha=0.3, label='ROC fold %d (AUC = %0.2f)' % (i, roc_auc))

        i += 1

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    plt.plot(mean_fpr, mean_tpr, color='r',
             label=r'Mean ROC Regression (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
             lw=2, alpha=.8)

    plt.rcParams["figure.figsize"] = [15,9]

    std_tpr = np.std(tprs, axis=0)
    tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
    tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
    #plt.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')

    plt.plot(mean_fpr, tprs_lower, '--', color='r',
             label=r'Mean ROC Regression STD',
             lw=1, alpha=.8)

    plt.plot(mean_fpr, tprs_upper, '--', color='r',
             #label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
             lw=1, alpha=.8)

    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Threshold='+str(threshold)+"/Sample="+str(sr))
    plt.legend(loc="lower right")
    plt.savefig('results2/ROC_'+filename+'_'+str(threshold)+'_'+str(sr)+'.png')
    plt.clf()
