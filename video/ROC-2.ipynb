# %%
import pandas as pd

resultsList = pd.read_csv("./data2/results-list.csv")

# %%
resultsList
# Out:
#      class_weight criterion     file  max_depth  max_features  max_leaf_nodes  \
# 0             NaN   entropy  dataset        NaN           NaN              10
# 1             NaN       mse  dataset        NaN           NaN              10
# 2             NaN   entropy  dataset        NaN           NaN              10
# 3             NaN       mse  dataset        NaN           NaN              10
# 4             NaN   entropy  dataset        NaN           NaN              10
# 5             NaN       mse  dataset        NaN           NaN              10
# 6             NaN   entropy  dataset        NaN           NaN              10
# 7             NaN       mse  dataset        NaN           NaN              10
# 8             NaN   entropy  dataset        NaN           NaN              10
# 9             NaN       mse  dataset        NaN           NaN              10
# 10            NaN   entropy  dataset        NaN           NaN              10
# 11            NaN       mse  dataset        NaN           NaN              10
# 12            NaN   entropy  dataset        NaN           NaN              20
# 13            NaN       mse  dataset        NaN           NaN              20
# 14            NaN   entropy  dataset        NaN           NaN              20
# 15            NaN       mse  dataset        NaN           NaN              20
# 16            NaN   entropy  dataset        NaN           NaN              20
# 17            NaN       mse  dataset        NaN           NaN              20
# 18            NaN   entropy  dataset        NaN           NaN              20
# 19            NaN       mse  dataset        NaN           NaN              20
# 20            NaN   entropy  dataset        NaN           NaN              20
# 21            NaN       mse  dataset        NaN           NaN              20
# 22            NaN   entropy  dataset        NaN           NaN              20
# 23            NaN       mse  dataset        NaN           NaN              20
# 24            NaN   entropy  dataset        NaN           NaN              30
# 25            NaN       mse  dataset        NaN           NaN              30
# 26            NaN   entropy  dataset        NaN           NaN              30
# 27            NaN       mse  dataset        NaN           NaN              30
# 28            NaN   entropy  dataset        NaN           NaN              30
# 29            NaN       mse  dataset        NaN           NaN              30
# ..            ...       ...      ...        ...           ...             ...
# 618           NaN   entropy  dataset       50.0           NaN              70
# 619           NaN       mse  dataset       50.0           NaN              70
# 620           NaN   entropy  dataset       50.0           NaN              70
# 621           NaN       mse  dataset       50.0           NaN              70
# 622           NaN   entropy  dataset       50.0           NaN              70
# 623           NaN       mse  dataset       50.0           NaN              70
# 624           NaN   entropy  dataset       50.0           NaN              80
# 625           NaN       mse  dataset       50.0           NaN              80
# 626           NaN   entropy  dataset       50.0           NaN              80
# 627           NaN       mse  dataset       50.0           NaN              80
# 628           NaN   entropy  dataset       50.0           NaN              80
# 629           NaN       mse  dataset       50.0           NaN              80
# 630           NaN   entropy  dataset       50.0           NaN              80
# 631           NaN       mse  dataset       50.0           NaN              80
# 632           NaN   entropy  dataset       50.0           NaN              80
# 633           NaN       mse  dataset       50.0           NaN              80
# 634           NaN   entropy  dataset       50.0           NaN              80
# 635           NaN       mse  dataset       50.0           NaN              80
# 636           NaN   entropy  dataset       50.0           NaN              90
# 637           NaN       mse  dataset       50.0           NaN              90
# 638           NaN   entropy  dataset       50.0           NaN              90
# 639           NaN       mse  dataset       50.0           NaN              90
# 640           NaN   entropy  dataset       50.0           NaN              90
# 641           NaN       mse  dataset       50.0           NaN              90
# 642           NaN   entropy  dataset       50.0           NaN              90
# 643           NaN       mse  dataset       50.0           NaN              90
# 644           NaN   entropy  dataset       50.0           NaN              90
# 645           NaN       mse  dataset       50.0           NaN              90
# 646           NaN   entropy  dataset       50.0           NaN              90
# 647           NaN       mse  dataset       50.0           NaN              90
#
#      min_impurity_decrease  min_samples_leaf  min_samples_split  \
# 0             1.000000e-07                 1                  2
# 1             1.000000e-07                 1                  2
# 2             1.000000e-07                 2                  2
# 3             1.000000e-07                 2                  2
# 4             1.000000e-07                 4                  2
# 5             1.000000e-07                 4                  2
# 6             1.000000e-07                 6                  2
# 7             1.000000e-07                 6                  2
# 8             1.000000e-07                 8                  2
# 9             1.000000e-07                 8                  2
# 10            1.000000e-07                10                  2
# 11            1.000000e-07                10                  2
# 12            1.000000e-07                 1                  2
# 13            1.000000e-07                 1                  2
# 14            1.000000e-07                 2                  2
# 15            1.000000e-07                 2                  2
# 16            1.000000e-07                 4                  2
# 17            1.000000e-07                 4                  2
# 18            1.000000e-07                 6                  2
# 19            1.000000e-07                 6                  2
# 20            1.000000e-07                 8                  2
# 21            1.000000e-07                 8                  2
# 22            1.000000e-07                10                  2
# 23            1.000000e-07                10                  2
# 24            1.000000e-07                 1                  2
# 25            1.000000e-07                 1                  2
# 26            1.000000e-07                 2                  2
# 27            1.000000e-07                 2                  2
# 28            1.000000e-07                 4                  2
# 29            1.000000e-07                 4                  2
# ..                     ...               ...                ...
# 618           1.000000e-07                 6                  2
# 619           1.000000e-07                 6                  2
# 620           1.000000e-07                 8                  2
# 621           1.000000e-07                 8                  2
# 622           1.000000e-07                10                  2
# 623           1.000000e-07                10                  2
# 624           1.000000e-07                 1                  2
# 625           1.000000e-07                 1                  2
# 626           1.000000e-07                 2                  2
# 627           1.000000e-07                 2                  2
# 628           1.000000e-07                 4                  2
# 629           1.000000e-07                 4                  2
# 630           1.000000e-07                 6                  2
# 631           1.000000e-07                 6                  2
# 632           1.000000e-07                 8                  2
# 633           1.000000e-07                 8                  2
# 634           1.000000e-07                10                  2
# 635           1.000000e-07                10                  2
# 636           1.000000e-07                 1                  2
# 637           1.000000e-07                 1                  2
# 638           1.000000e-07                 2                  2
# 639           1.000000e-07                 2                  2
# 640           1.000000e-07                 4                  2
# 641           1.000000e-07                 4                  2
# 642           1.000000e-07                 6                  2
# 643           1.000000e-07                 6                  2
# 644           1.000000e-07                 8                  2
# 645           1.000000e-07                 8                  2
# 646           1.000000e-07                10                  2
# 647           1.000000e-07                10                  2
#
#      min_weight_fraction_leaf  presort  random_state  \
# 0                         0.0    False           NaN
# 1                         0.0    False           NaN
# 2                         0.0    False           NaN
# 3                         0.0    False           NaN
# 4                         0.0    False           NaN
# 5                         0.0    False           NaN
# 6                         0.0    False           NaN
# 7                         0.0    False           NaN
# 8                         0.0    False           NaN
# 9                         0.0    False           NaN
# 10                        0.0    False           NaN
# 11                        0.0    False           NaN
# 12                        0.0    False           NaN
# 13                        0.0    False           NaN
# 14                        0.0    False           NaN
# 15                        0.0    False           NaN
# 16                        0.0    False           NaN
# 17                        0.0    False           NaN
# 18                        0.0    False           NaN
# 19                        0.0    False           NaN
# 20                        0.0    False           NaN
# 21                        0.0    False           NaN
# 22                        0.0    False           NaN
# 23                        0.0    False           NaN
# 24                        0.0    False           NaN
# 25                        0.0    False           NaN
# 26                        0.0    False           NaN
# 27                        0.0    False           NaN
# 28                        0.0    False           NaN
# 29                        0.0    False           NaN
# ..                        ...      ...           ...
# 618                       0.0    False           NaN
# 619                       0.0    False           NaN
# 620                       0.0    False           NaN
# 621                       0.0    False           NaN
# 622                       0.0    False           NaN
# 623                       0.0    False           NaN
# 624                       0.0    False           NaN
# 625                       0.0    False           NaN
# 626                       0.0    False           NaN
# 627                       0.0    False           NaN
# 628                       0.0    False           NaN
# 629                       0.0    False           NaN
# 630                       0.0    False           NaN
# 631                       0.0    False           NaN
# 632                       0.0    False           NaN
# 633                       0.0    False           NaN
# 634                       0.0    False           NaN
# 635                       0.0    False           NaN
# 636                       0.0    False           NaN
# 637                       0.0    False           NaN
# 638                       0.0    False           NaN
# 639                       0.0    False           NaN
# 640                       0.0    False           NaN
# 641                       0.0    False           NaN
# 642                       0.0    False           NaN
# 643                       0.0    False           NaN
# 644                       0.0    False           NaN
# 645                       0.0    False           NaN
# 646                       0.0    False           NaN
# 647                       0.0    False           NaN
#
#                                    results splitter
# 0    ./data2/video-0001-classification.csv     best
# 1        ./data2/video-0001-regression.csv     best
# 2    ./data2/video-0002-classification.csv     best
# 3        ./data2/video-0002-regression.csv     best
# 4    ./data2/video-0003-classification.csv     best
# 5        ./data2/video-0003-regression.csv     best
# 6    ./data2/video-0004-classification.csv     best
# 7        ./data2/video-0004-regression.csv     best
# 8    ./data2/video-0005-classification.csv     best
# 9        ./data2/video-0005-regression.csv     best
# 10   ./data2/video-0006-classification.csv     best
# 11       ./data2/video-0006-regression.csv     best
# 12   ./data2/video-0007-classification.csv     best
# 13       ./data2/video-0007-regression.csv     best
# 14   ./data2/video-0008-classification.csv     best
# 15       ./data2/video-0008-regression.csv     best
# 16   ./data2/video-0009-classification.csv     best
# 17       ./data2/video-0009-regression.csv     best
# 18   ./data2/video-0010-classification.csv     best
# 19       ./data2/video-0010-regression.csv     best
# 20   ./data2/video-0011-classification.csv     best
# 21       ./data2/video-0011-regression.csv     best
# 22   ./data2/video-0012-classification.csv     best
# 23       ./data2/video-0012-regression.csv     best
# 24   ./data2/video-0013-classification.csv     best
# 25       ./data2/video-0013-regression.csv     best
# 26   ./data2/video-0014-classification.csv     best
# 27       ./data2/video-0014-regression.csv     best
# 28   ./data2/video-0015-classification.csv     best
# 29       ./data2/video-0015-regression.csv     best
# ..                                     ...      ...
# 618  ./data2/video-0310-classification.csv     best
# 619      ./data2/video-0310-regression.csv     best
# 620  ./data2/video-0311-classification.csv     best
# 621      ./data2/video-0311-regression.csv     best
# 622  ./data2/video-0312-classification.csv     best
# 623      ./data2/video-0312-regression.csv     best
# 624  ./data2/video-0313-classification.csv     best
# 625      ./data2/video-0313-regression.csv     best
# 626  ./data2/video-0314-classification.csv     best
# 627      ./data2/video-0314-regression.csv     best
# 628  ./data2/video-0315-classification.csv     best
# 629      ./data2/video-0315-regression.csv     best
# 630  ./data2/video-0316-classification.csv     best
# 631      ./data2/video-0316-regression.csv     best
# 632  ./data2/video-0317-classification.csv     best
# 633      ./data2/video-0317-regression.csv     best
# 634  ./data2/video-0318-classification.csv     best
# 635      ./data2/video-0318-regression.csv     best
# 636  ./data2/video-0319-classification.csv     best
# 637      ./data2/video-0319-regression.csv     best
# 638  ./data2/video-0320-classification.csv     best
# 639      ./data2/video-0320-regression.csv     best
# 640  ./data2/video-0321-classification.csv     best
# 641      ./data2/video-0321-regression.csv     best
# 642  ./data2/video-0322-classification.csv     best
# 643      ./data2/video-0322-regression.csv     best
# 644  ./data2/video-0323-classification.csv     best
# 645      ./data2/video-0323-regression.csv     best
# 646  ./data2/video-0324-classification.csv     best
# 647      ./data2/video-0324-regression.csv     best
#
# [648 rows x 14 columns]

# %%
serie = []
for i in resultsList['results']:
    serie.append(i.split("-")[2].split(".")[0])

serie = pd.Series(serie)

resultsList['type'] = serie

accuracy = []
accuracy_N = []
accuracy_3N = []
accuracy_5N = []
mse = []
for i in resultsList['results']:
    dfTemp = pd.read_csv(i)
    dfMean = dfTemp.groupby(['sr']).mean()
    dfMean['accuracy']= (dfMean['TP']+dfMean['TN']) / (dfMean['TP']+dfMean['TN']+dfMean['FN']+dfMean['FP'])
    accuracy.append(dfMean['accuracy'].mean())
    accuracy_N.append(((dfTemp[:1]['TP']+dfTemp[:1]['TN']) / (dfTemp[:1]['TP']+dfTemp[:1]['TN']+dfTemp[:1]['FN']+dfTemp[:1]['FP'])).mean())
    accuracy_3N.append(((dfTemp[2:3]['TP']+dfTemp[2:3]['TN']) / (dfTemp[2:3]['TP']+dfTemp[2:3]['TN']+dfTemp[2:3]['FN']+dfTemp[2:3]['FP'])).mean())
    accuracy_5N.append(((dfTemp[4:5]['TP']+dfTemp[4:5]['TN']) / (dfTemp[4:5]['TP']+dfTemp[4:5]['TN']+dfTemp[4:5]['FN']+dfTemp[4:5]['FP'])).mean())
    if 'MSE' in dfMean.columns:
        mse.append(dfMean['MSE'].mean())
    else:
        mse.append(None)
    print(accuracy_N)
    break
resultsList['mse'] = pd.Series(mse)
resultsList['accuracy'] = pd.Series(accuracy)
#resultsList['accuracy_N'] = pd.Series(accuracy_N)
#resultsList['accuracy_3N'] = pd.Series(accuracy_3N)
#resultsList['accuracy_5N'] = pd.Series(accuracy_5N)

idx = resultsList.groupby(["file","type"])["accuracy"].transform(max) == resultsList['accuracy']
#resultsList[idx].sort_values(["file"])
# Out:
# [0.915496368038741]

# %%
configSet = []
resultsList2 = resultsList[idx][(resultsList['type'] == "classification") | (resultsList['type'] == "regression")].where(pd.notnull(resultsList), None)
for f in resultsList2.file.unique():
    for t in resultsList2.type.unique():
        for index, r in resultsList2.loc[(resultsList["file"]==f) & (resultsList2["type"]==t)].sort_values("accuracy", ascending=False)[:10].iterrows():
            configuration = {}
            for i in r.keys():
                if not i in ["results","type","accuracy","file","mse"]:
                    if not (r["type"] == "regression" and i=="class_weight"):
                        configuration[i] = r[i]
            configSet.append({"file":r["file"],"type":r["type"],"configuration":configuration})
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
import numpy as np
from scipy import interp
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn import tree

# %%
dfConfig = pd.DataFrame(configSet)

d = pd.read_csv("./dataset.csv")
#d = d.sort_values(by="perf")

perf="value that led to label"
label="label (0 if usable and 1 if not)"

srm = 100
srM = d.shape[0]
srs = 100
NSUBS = 10

t=0.5
n = d.shape[1] - 2

for sr in [n,2*n,3*n,4*n,5*n]:
    shuffle_split = StratifiedShuffleSplit(train_size=sr, n_splits=NSUBS)

    classifier = tree.DecisionTreeClassifier(**dfConfig[dfConfig['type'] == "classification"].configuration.values[0])
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    i = 0
    for train, test in shuffle_split.split(d,d[label]):
        #.fit(d.drop([perf,label],axis=1).iloc[train_index], d[perf].iloc[train_index])
        #probas_ = classifier.fit(d.drop([perf,label],axis=1).iloc[train], d[perf].iloc[train]).predict_proba(d.drop([perf,label],axis=1).iloc[test])
        probas_ = classifier.fit(d.drop([perf,label],axis=1).iloc[train], d[label].iloc[train]).predict_proba(d.drop([perf,label],axis=1).iloc[test])
        # Compute ROC curve and area the curve
        fpr, tpr, thresholds = roc_curve(d[label].iloc[test], probas_[:, 1])
        #print(thresholds)
        tprs.append(interp(mean_fpr, fpr, tpr))
        tprs[-1][0] = 0.0
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)
        #plt.plot(fpr, tpr, lw=1, alpha=0.3, label='ROC fold %d (AUC = %0.2f)' % (i, roc_auc))

        i += 1

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    plt.plot(mean_fpr, mean_tpr, color='b',
             label=r'Mean ROC Classification (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
             lw=2, alpha=.8)

    plt.rcParams["figure.figsize"] = [15,9]

    std_tpr = np.std(tprs, axis=0)
    tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
    tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
    #plt.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')

    plt.plot(mean_fpr, tprs_lower, '--', color='b',
             label=r'Mean ROC Classification STD',
             lw=1, alpha=.8)

    plt.plot(mean_fpr, tprs_upper, '--', color='b',
             #label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
             lw=1, alpha=.8)
    '''
    d = pd.read_csv(datasetPath+filename+".csv")

    d["label"] = 0
    d.loc[d["perf"] > threshold, "label"] = 1

    X = d.drop(["perf","label"],axis=1,errors="ignore")
    y = d["perf"]
    y_split = d["label"]'''

    classifier = tree.DecisionTreeRegressor(**dfConfig[dfConfig['type'] == "regression"].configuration.values[0])
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    i = 0
    for _ in range(1,11):
        for train, test in shuffle_split.split(d,d[label]):
            #.fit(d.drop([perf,label],axis=1).iloc[train], d[perf].iloc[train]).predict_proba(d.drop([perf,label],axis=1).iloc[test])
            probas_ = classifier.fit(d.drop([perf,label],axis=1).iloc[train], d[perf].iloc[train]).predict(d.drop([perf,label],axis=1).iloc[test]) > t
            # Compute ROC curve and area the curve
            fpr, tpr, thresholds = roc_curve(d[perf].iloc[test] > t, probas_)
            #print(thresholds)
            tprs.append(interp(mean_fpr, fpr, tpr))
            tprs[-1][0] = 0.0
            roc_auc = auc(fpr, tpr)
            aucs.append(roc_auc)
            #plt.plot(fpr, tpr, lw=1, alpha=0.3, label='ROC fold %d (AUC = %0.2f)' % (i, roc_auc))

            i += 1

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    plt.plot(mean_fpr, mean_tpr, color='r',
             label=r'Mean ROC Regression (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
             lw=2, alpha=.8)

    plt.rcParams["figure.figsize"] = [15,9]

    std_tpr = np.std(tprs, axis=0)
    tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
    tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
    #plt.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,label=r'$\pm$ 1 std. dev.')

    plt.plot(mean_fpr, tprs_lower, '--', color='r',
             label=r'Mean ROC Regression STD',
             lw=1, alpha=.8)

    plt.plot(mean_fpr, tprs_upper, '--', color='r',
             #label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
             lw=1, alpha=.8)

    plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='#000000',
             label='Luck', alpha=.8)
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Threshold='+str(t)+"/Sample="+str(sr))
    plt.legend(loc="lower right")
    plt.savefig('./results2/ROC_video_'+str(t)+'_'+str(sr)+'.png')
    plt.clf()
# Out:
# /usr/lib64/python3.6/site-packages/sklearn/model_selection/_split.py:1639: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
